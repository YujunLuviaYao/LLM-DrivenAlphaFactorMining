# %% [markdown]
# # Opt3: NumPy arrays + Bottleneck
#
# Built on Opt2. This version strips pandas from the hot path:
#
# - Input panels are converted to `np.ndarray` **once** at backtester init. All
#   operators work on raw arrays; no `.values` conversion per call, no pandas
#   index-alignment overhead.
# - `ts_mean / ts_std / ts_max / ts_min` → `bottleneck.move_*`. Bottleneck's
#   rolling kernels are 3–5× faster than pandas' (hand-tuned C, no axis/index
#   machinery).
# - `ts_corr` is **composed** from bottleneck primitives — there is no
#   `bn.move_corr`, so we build it from
#   `corr = (E[xy] − E[x]E[y]) / (std(x)·std(y))`
#   using `bn.move_mean` on `x`, `y`, `x*y` plus `bn.move_std`. Measured ~4×
#   faster than `pandas.DataFrame.rolling().corr()`.
# - `rank / zscore` → vectorized NumPy reductions along axis=1. `rank` uses
#   `scipy.stats.rankdata` applied row-wise for NaN-aware percentile ranks
#   matching pandas semantics.
# - `sign / log / abs / power` → NumPy ufuncs.
# - `compute_factor` wraps the final NumPy result back into a DataFrame so that
#   Part 4 (evaluation) and Part 5 (plotting) continue to work unchanged.
#
# Expected: ~3–5× over Opt2 (so ~3–5s for `compute_all_factors`, down from ~15s).
# The remaining hotspot is `ts_corr`; if you want another order of magnitude,
# Numba-JIT it in Opt4.

# %%
import os
import re
import json
import ast
import time
import warnings
import pickle

import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from tqdm.auto import tqdm

# %%
# Initialize timing dictionary to collect execution times
timing = {}

# %% [markdown]
# ## Part 1: Data Loading

# %%
def get_tickers(n_stocks):
    df = pd.read_csv("../data/sp500_tickers.csv")
    tickers = df["ticker"].tolist()
    return tickers[:n_stocks]

def load_sp500_data(start, end, n_stocks, cache_path="../data/sp500_cache.pkl"):
    if os.path.exists(cache_path):
        print("Cache found, loading from disk...")
        with open(cache_path, "rb") as f:
            data = pickle.load(f)
        print(f"Loaded: {data['close'].shape[0]} days x {data['close'].shape[1]} stocks")
        return data
 
    import yfinance as yf
    tickers = get_tickers(n_stocks)
    # --- Download price data from Yahoo Finance ---
    print(f"Downloading data from {start} to {end} ...")
    raw = yf.download(tickers, start=start, end=end, auto_adjust=True, progress=True)
 
    # --- Extract each field into its own DataFrame ---
    close  = raw["Close"].ffill().bfill()
    open_  = raw["Open"].ffill().bfill()
    high   = raw["High"].ffill().bfill()
    low    = raw["Low"].ffill().bfill()
    volume = raw["Volume"].ffill().bfill()
 
    # Drop stocks that are missing more than 10% of data
    min_rows = int(len(close) * 0.9)
    close = close.dropna(thresh=min_rows, axis=1)
 
    # Keep only the stocks that survived the filter
    valid = close.columns
    open_, high, low, volume = open_[valid], high[valid], low[valid], volume[valid]
 
    # --- Derive extra fields needed for factor calculation ---
    vwap    = (high + low + close) / 3          # typical price, proxy for VWAP
    returns = close.pct_change().fillna(0)      # daily return
    adv20   = volume.rolling(20).mean().bfill() # 20-day average daily volume
 
    print(f"Done: {close.shape[0]} days x {close.shape[1]} stocks")
 
    data = {
        "open": open_, "high": high, "low": low,
        "close": close, "volume": volume,
        "vwap": vwap, "returns": returns, "adv20": adv20,
    }
 
    # --- Save to cache ---
    os.makedirs(os.path.dirname(cache_path), exist_ok=True)
    with open(cache_path, "wb") as f:
        pickle.dump(data, f)
    print(f"Saved to {cache_path}")
 
    return data

# %%
data = load_sp500_data(
    start    = "2023-01-01",
    end      = "2026-01-01",
    n_stocks = 500,
)
print(data["close"].head(3))
# Out:
# Cache found, loading from disk...
# Loaded: 752 days x 483 stocks
# Ticker               A    AAL        AAPL        ABBV       ABNB         ABT  \
# Date
# 2023-01-03  146.749939  12.74  123.096016  144.322632  84.900002  102.849213
# 2023-01-04  148.344147  13.59  124.365662  145.486938  88.720001  104.379097
# 2023-01-05  148.774521  13.99  123.046822  145.309204  87.709999  103.994286
#
# Ticker           ACGL         ACN        ADBE         ADI  ...         WTW  \
# Date                                                       ...
# 2023-01-03  59.393120  258.138916  336.920013  153.730545  ...  235.955490
# 2023-01-04  59.687901  257.260101  341.410004  157.004852  ...  237.216171
# 2023-01-05  59.849552  251.185394  328.440002  151.118698  ...  237.168060
#
# Ticker             WY       WYNN        XEL        XOM         XYL  \
# Date
# 2023-01-03  27.315928  83.030846  62.719933  95.434212  106.506363
# 2023-01-04  27.643436  88.161484  63.256966  95.711983  106.342880
# 2023-01-05  26.820244  88.588211  61.976974  97.853439  103.323471
#
# Ticker             YUM         ZBH        ZBRA         ZTS
# Date
# 2023-01-03  119.313332  123.997635  260.200012  141.600998
# 2023-01-04  120.929733  125.147217  262.989990  143.635590
# 2023-01-05  120.008774  122.828598  260.059998  140.251053
#
# [3 rows x 483 columns]

# %% [markdown]
# ## Part 2: Load cached factors
#
# Reuses the 216 factors generated and cached during the baseline run. No API call is made, so Opt2's factor set is byte-identical to baseline's — speedup comparisons are apples-to-apples.

# %%
# Load the factors cached from the baseline run.
# No API call is made — we reuse the exact same 216 factors so that
# Opt2's results are directly comparable to the baseline's.
with open("../results/evaluation/factors.json", "r") as f:
    factors = json.load(f)

print(f"Loaded {len(factors)} factors from cache")
for i, f in enumerate(factors[:5], 1):
    print(f"  {i}. {f['factor']}")
    print(f"     → {f['description']}")
print(f"  ... ({len(factors) - 5} more)")
# Out:
# Loaded 216 factors from cache
#   1. rank(ts_mean(close, 5) - ts_mean(close, 20))
#      → Rank of the difference between 5-day and 20-day closing price moving averages — captures short-term vs long-term price trend momentum.
#   2. rank(ts_mean(returns, 20) / ts_std(returns, 20))
#      → Rank of 20-day average daily return divided by 20-day standard deviation of returns — captures volatility-adjusted momentum (Sharpe-ratio like).
#   3. rank(close - ts_min(low, 20))
#      → Rank of today's closing price relative to the 20-day minimum low price — identifies stocks consistently closing significantly above their recent lows, indicating upward momentum.
#   4. rank(ts_delta(vwap, 10) * (volume / adv20))
#      → Rank of 10-day VWAP change multiplied by today's volume relative to its 20-day average volume — combines VWAP momentum with volume confirmation.
#   5. rank(ts_mean(close - open, 5))
#      → Rank of the 5-day average of (closing price - opening price) — captures consistent daily intra-day upward momentum (stocks regularly closing higher than they opened).
#   ... (211 more)

# %% [markdown]
# ## Part 3: Backtesting framework (Opt3 — NumPy + Bottleneck)

# %%
import bottleneck as bn


class Opt3Backtester:
    """
    NumPy + Bottleneck implementation of the baseline operators.

    Design:
      - Inputs are stored as np.ndarray internally. The original DataFrame
        index/columns are kept once at __init__ so we can wrap the final
        factor output back into a DataFrame for downstream code.
      - Intermediate operator results stay as ndarrays — no round-tripping
        through pandas until compute_factor() is done.
      - Operators preserve the baseline's NaN conventions:
          * Warmup rows (first d-1) in time-series ops stay NaN
          * ts_corr windows with zero std get 0.0 (baseline guard)
          * sign(NaN) → 0.0 (quirk preserved from baseline)
    """

    def __init__(self, data):
        # Cache the original pandas index/columns so we can rebuild DataFrames
        # at the end of compute_factor. Use `close` as the reference shape.
        close_df = data["close"]
        self._index = close_df.index
        self._columns = close_df.columns

        # Store every field as a contiguous float64 ndarray. float64 matches
        # pandas default and avoids bottleneck dtype-dispatch surprises.
        self.data = {
            k: np.ascontiguousarray(v.values, dtype=np.float64)
            for k, v in data.items()
        }

    # ── Helpers ──────────────────────────────────────────────────────────────

    def _wrap(self, arr):
        """Convert an ndarray result back into a DataFrame with original labels."""
        return pd.DataFrame(arr, index=self._index, columns=self._columns)

    # ── Time-series operators (bottleneck: one C call per op, no pandas) ────

    def ts_mean(self, x, d):
        return bn.move_mean(x, window=d, axis=0)

    def ts_std(self, x, d):
        # ddof=1 matches pandas' default sample std (and the baseline's .std())
        return bn.move_std(x, window=d, axis=0, ddof=1)

    def ts_delta(self, x, d):
        # Manual shift: allocate output, fill first d rows with NaN, then diff.
        out = np.empty_like(x)
        out[:d] = np.nan
        out[d:] = x[d:] - x[:-d]
        return out

    def ts_max(self, x, d):
        return bn.move_max(x, window=d, axis=0)

    def ts_min(self, x, d):
        return bn.move_min(x, window=d, axis=0)

    def ts_corr(self, x, y, d):
        # Rolling same-ticker Pearson correlation between x and y.
        # Bottleneck has no move_corr, so we compose from primitives:
        #
        #   corr(x,y) = (E[xy] - E[x]·E[y]) / (std(x) · std(y))
        #
        # where all E[.] are rolling window means and std is the sample std
        # (ddof=1) to match pandas. This is ~4× faster than pandas' rolling
        # corr on the 752×483 panel.
        ex  = bn.move_mean(x,     window=d, axis=0)
        ey  = bn.move_mean(y,     window=d, axis=0)
        exy = bn.move_mean(x * y, window=d, axis=0)
        sx  = bn.move_std(x,  window=d, axis=0, ddof=1)
        sy  = bn.move_std(y,  window=d, axis=0, ddof=1)

        # Rescale E[xy] - E[x]E[y] (which is the population covariance over the
        # window) to sample covariance: multiply by d/(d-1). This makes the
        # numerator consistent with the ddof=1 std used in the denominator.
        cov_sample = (exy - ex * ey) * (d / (d - 1))

        denom = sx * sy
        with np.errstate(invalid="ignore", divide="ignore"):
            corr = np.where(denom > 0, cov_sample / denom, 0.0)

        # Preserve warmup NaN (first d-1 rows).
        corr[: d - 1] = np.nan
        return corr

    # ── Cross-sectional operators (vectorized across stocks per date) ───────

    def rank(self, x):
        # Percentile rank across columns for each row, NaN-aware.
        # bn.nanrankdata is a single C-level call that:
        #   - ignores NaNs (leaves them as NaN in the output)
        #   - uses average method for ties (matches pandas' rank() default)
        # Dividing by the per-row count of non-NaN entries gives the percentile
        # rank (matches pandas' rank(pct=True)).
        ranks = bn.nanrankdata(x, axis=1)
        n_valid = (~np.isnan(x)).sum(axis=1, keepdims=True).astype(np.float64)
        with np.errstate(invalid="ignore", divide="ignore"):
            return ranks / n_valid

    def zscore(self, x):
        # Cross-sectional z-score: (x - row_mean) / row_std, NaN-aware.
        # bn.nanmean/nanstd are faster than np.nanmean/nanstd.
        mu    = bn.nanmean(x, axis=1)[:, None]
        sigma = bn.nanstd(x, axis=1, ddof=1)[:, None]
        with np.errstate(invalid="ignore", divide="ignore"):
            z = (x - mu) / sigma
        # Baseline's rule: if sigma==0 on a row, set that row to 0.0
        # (matches the 'if sigma == 0: result.iloc[i] = 0.0' branch).
        zero_std_rows = (sigma[:, 0] == 0) | np.isnan(sigma[:, 0])
        if zero_std_rows.any():
            # Only zero the rows where sigma is actually 0, not where it's NaN
            # due to all-NaN input (those should stay NaN, but baseline zero'd
            # them too via the `if sigma == 0` path — sigma of NaN evaluates
            # False, so those rows stayed NaN. Replicate that.)
            truly_zero = sigma[:, 0] == 0
            z[truly_zero] = 0.0
        # inf → 0.0 (division safety)
        z[np.isinf(z)] = 0.0
        return z

    # ── Math operators (NumPy ufuncs) ───────────────────────────────────────

    def sign(self, x):
        # Preserve baseline quirk: sign(NaN) → 0.0
        out = np.sign(x)
        out[np.isnan(out)] = 0.0
        return out

    def log(self, x):
        # Clamp at 1e-9 to avoid -inf, matching baseline.
        return np.log(np.maximum(x, 1e-9))

    def abs(self, x):
        return np.abs(x)

    def power(self, x, n):
        return x ** n

    # ── Factor computation ──────────────────────────────────────────────────

    def compute_factor(self, expr):
        ctx = {
            "open":    self.data["open"],
            "high":    self.data["high"],
            "low":     self.data["low"],
            "close":   self.data["close"],
            "volume":  self.data["volume"],
            "vwap":    self.data["vwap"],
            "returns": self.data["returns"],
            "adv20":   self.data["adv20"],
            "ts_mean":  self.ts_mean,
            "ts_std":   self.ts_std,
            "ts_delta": self.ts_delta,
            "ts_max":   self.ts_max,
            "ts_min":   self.ts_min,
            "ts_corr":  self.ts_corr,
            "rank":     self.rank,
            "zscore":   self.zscore,
            "sign":     self.sign,
            "log":      self.log,
            "abs":      self.abs,
            "power":    self.power,
        }
        result = eval(expr, {"__builtins__": {}}, ctx)
        # Result may be a scalar-times-array (e.g. `-1 * rank(...)`) — ensure
        # we always return a DataFrame so downstream code is happy.
        if isinstance(result, np.ndarray):
            return self._wrap(result)
        # Fallback: if somehow a pandas object leaked through (shouldn't happen).
        return result


def compute_all_factors(factors, data):
    bt = Opt3Backtester(data)
    results = {}

    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        progress = tqdm(factors, desc="Computing factors", unit="factor")
        for f in progress:
            expr = f["factor"]
            progress.set_postfix_str(expr[:60], refresh=False)
            try:
                result = bt.compute_factor(expr)
                results[expr] = result
            except Exception as e:
                tqdm.write(f"Failed: {expr} -> {e}")

    print(f"Done: {len(results)}/{len(factors)} factors computed successfully")
    return results

# %%
with open("../results/evaluation/factors.json", "r") as f:
    factors = json.load(f)
print(f"Loaded {len(factors)} factors from ../results/evaluation/factors.json")

# Compute all factors
start = time.time()
factor_results = compute_all_factors(factors, data)
end = time.time()
timing['compute_all_factors'] = end - start
print(f"Time for compute_all_factors: {timing['compute_all_factors']:.2f} seconds")

# Print a sample of one factor's output
sample_expr   = list(factor_results.keys())[0]
sample_matrix = factor_results[sample_expr]
print(f"\nSample output for: {sample_expr}")
print(sample_matrix.iloc[:3, :5])
print(sample_matrix.iloc[25:28, :5])  # Skip the first 20 rows and inspect again
# Out:
# Loaded 216 factors from ../results/evaluation/factors.json
# Computing factors:   0%|          | 0/216 [00:00<?, ?factor/s]
# Done: 216/216 factors computed successfully
# Time for compute_all_factors: 3.66 seconds
#
# Sample output for: rank(ts_mean(close, 5) - ts_mean(close, 20))
# Ticker       A  AAL  AAPL  ABBV  ABNB
# Date
# 2023-01-03 NaN  NaN   NaN   NaN   NaN
# 2023-01-04 NaN  NaN   NaN   NaN   NaN
# 2023-01-05 NaN  NaN   NaN   NaN   NaN
# Ticker             A       AAL      AAPL      ABBV      ABNB
# Date
# 2023-02-08  0.207039  0.412008  0.908903  0.074534  0.915114
# 2023-02-09  0.202899  0.445135  0.913043  0.128364  0.910973
# 2023-02-10  0.182195  0.451346  0.919255  0.279503  0.902692

# %% [markdown]
# ## Part 4: Performance evaluation

# %%
from scipy import stats
def compute_ic_series(factor, returns, forward_days=1):
    """
    For each day, compute the Spearman correlation between:
      - today's factor value (across all stocks)
      - tomorrow's actual return (across all stocks)
 
    A positive IC means the factor correctly predicted which stocks would go up.
    Returns a time series of daily IC values.
    """
    fwd_returns = returns.shift(-forward_days)
    ic_list = []
 
    for date in factor.index:
        f_row = factor.loc[date]
        r_row = fwd_returns.loc[date]
 
        valid = f_row.notna() & r_row.notna()
        if valid.sum() < 10:
            ic_list.append(np.nan)
            continue
 
        corr, _ = stats.spearmanr(f_row[valid], r_row[valid])
        ic_list.append(corr)
 
    return pd.Series(ic_list, index=factor.index)
 
 
def compute_long_short_returns(factor, returns, quantile=0.1, forward_days=1):
    """
    Build a long-short portfolio each day:
      - Long:  top quantile stocks by factor value (e.g. top 10%)
      - Short: bottom quantile stocks by factor value (e.g. bottom 10%)
      - Daily P&L = average long return - average short return
 
    Returns a time series of daily portfolio returns.
    """
    fwd_returns = returns.shift(-forward_days)
    port_returns = []
 
    for date in factor.index[:-forward_days]:
        f_row = factor.loc[date]
        r_row = fwd_returns.loc[date]
        valid = f_row.notna() & r_row.notna()
 
        if valid.sum() < 20:
            port_returns.append(np.nan)
            continue
 
        f_valid = f_row[valid]
        r_valid = r_row[valid]
        n = len(f_valid)
        k = max(1, int(n * quantile))
 
        ranked     = f_valid.rank()
        long_ret   = r_valid[ranked >= (n - k + 1)].mean()
        short_ret  = r_valid[ranked <= k].mean()
        port_returns.append(long_ret - short_ret)
 
    return pd.Series(port_returns, index=factor.index[:-forward_days])
 
 
def evaluate_factor(factor, returns, forward_days=1, quantile=0.1):
    """
    Compute all five metrics for a single factor.
    Returns a dict of scores.
    """
    # IC and ICIR
    ic = compute_ic_series(factor, returns, forward_days).dropna()
    ic_mean = ic.mean()
    ic_std  = ic.std()
    icir    = ic_mean / ic_std if ic_std > 0 else 0.0
 
    # Long-short portfolio
    ls_ret = compute_long_short_returns(factor, returns, quantile, forward_days).dropna()
 
    # Sharpe (annualized)
    sharpe = (ls_ret.mean() / ls_ret.std() * np.sqrt(252)) if ls_ret.std() > 0 else 0.0
 
    # Max Drawdown
    nav = (1 + ls_ret).cumprod()
    mdd = ((nav - nav.cummax()) / nav.cummax()).min()
 
    # Turnover: how much the stock selection changes each day
    turnover_list = []
    prev = None
    for date in factor.index:
        f_row = factor.loc[date]
        valid = f_row.notna()
        if valid.sum() < 20:
            continue
        f_valid = f_row[valid]
        n = len(f_valid)
        k = max(1, int(n * quantile))
        ranked = f_valid.rank()
        curr   = set(f_valid[ranked >= (n - k + 1)].index) | set(f_valid[ranked <= k].index)
        if prev is not None:
            changed = len(curr.symmetric_difference(prev))
            total   = len(curr) + len(prev)
            turnover_list.append(changed / total if total > 0 else 0)
        prev = curr
    turnover = np.mean(turnover_list) if turnover_list else np.nan
 
    return {
        "IC_mean": round(ic_mean, 4),
        "ICIR":    round(icir, 4),
        "Sharpe":  round(sharpe, 4),
        "MDD":     round(mdd, 4),
        "Turnover":round(turnover, 4),
    }
 
 
# ── Evaluate all factors and rank them ────────────────────────────────────────
 
def evaluate_all_factors(factor_results, returns):
    """
    Run evaluate_factor() for every factor.
    Returns a DataFrame sorted by composite score (best factor first).
    """
    rows = []
 
    for i, (expr, factor_df) in enumerate(factor_results.items(), 1):
        print(f"[{i}/{len(factor_results)}] Evaluating: {expr[:60]}")
        metrics         = evaluate_factor(factor_df, returns)
        metrics["factor"] = expr
        rows.append(metrics)
 
    df = pd.DataFrame(rows)
 
    # Composite score: normalize each metric to 0-1 then take weighted average
    def minmax(s):
        rng = s.max() - s.min()
        return (s - s.min()) / rng if rng > 0 else pd.Series(0.5, index=s.index)
 
    df["score"] = (
        minmax(df["ICIR"])         * 0.35 +
        minmax(df["Sharpe"])       * 0.30 +
        minmax(df["IC_mean"])      * 0.15 +
        minmax(-df["MDD"])         * 0.15 +  # closer to 0 is better, so negate
        minmax(-df["Turnover"])    * 0.05     # lower turnover is better, so negate
    ).round(4)
 
    df = df.sort_values("score", ascending=False).reset_index(drop=True)
    df.index = range(1, len(df) + 1)
    df.index.name = "rank"
 
    return df

# %%
returns = data["returns"]

# Load factors
with open("../results/evaluation/factors.json") as f:
    factors = json.load(f)

# Compute factor matrices (Part 3)
factor_results = compute_all_factors(factors, data)

# Evaluate and rank (Part 4)
start = time.time()
results = evaluate_all_factors(factor_results, returns)
end = time.time()
timing['evaluate_all_factors'] = end - start
print(f"Time for evaluate_all_factors: {timing['evaluate_all_factors']:.2f} seconds")

# Print results
print("\nFactor ranking:")
print(results[["factor", "IC_mean", "ICIR", "Sharpe", "MDD", "Turnover", "score"]].to_string())

# Save to CSV
results.to_csv("../results/evaluation/factor_evaluation.csv")
print("\nSaved to ../results/evaluation/factor_evaluation.csv")
# Out:
# Computing factors:   0%|          | 0/216 [00:00<?, ?factor/s]
# Done: 216/216 factors computed successfully
# [1/216] Evaluating: rank(ts_mean(close, 5) - ts_mean(close, 20))
# [2/216] Evaluating: rank(ts_mean(returns, 20) / ts_std(returns, 20))
# [3/216] Evaluating: rank(close - ts_min(low, 20))
# [4/216] Evaluating: rank(ts_delta(vwap, 10) * (volume / adv20))
# [5/216] Evaluating: rank(ts_mean(close - open, 5))
# [6/216] Evaluating: rank((ts_mean(close, 20) - close) / ts_std(close, 20))
# [7/216] Evaluating: rank(open / close)
# [8/216] Evaluating: rank(ts_mean(returns, 20) - ts_mean(returns, 5))
# [9/216] Evaluating: rank((ts_max(high, 20) - close) / (ts_max(high, 20) - ts_min
# [10/216] Evaluating: rank(log(volume / adv20) * sign(ts_delta(close, 5)))
# /var/folders/g6/7_gx55l93snbqgq_jbkch3yw0000gn/T/ipykernel_60281/1207720711.py:23: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, _ = stats.spearmanr(f_row[valid], r_row[valid])
# [11/216] Evaluating: rank(ts_corr(returns, volume / adv20, 10))
# [12/216] Evaluating: rank((close - vwap) * (volume / adv20))
# [13/216] Evaluating: rank(ts_mean(volume, 5) / ts_std(close, 5))
# [14/216] Evaluating: rank(ts_corr(ts_delta(close, 1), ts_delta(volume, 1), 20))
# [15/216] Evaluating: rank(-ts_corr(ts_delta(close, 5), ts_mean(volume, 5) - volum
# [16/216] Evaluating: rank(ts_std(returns, 5) / ts_std(returns, 20))
# [17/216] Evaluating: rank(ts_std(close / ts_mean(close, 10), 20))
# [18/216] Evaluating: rank((high - low) / ts_mean(high - low, 20))
# [19/216] Evaluating: rank(ts_std(returns, 10) * (volume / adv20))
# [20/216] Evaluating: rank(ts_std(ts_std(returns, 5), 20))
# [21/216] Evaluating: ts_delta(close, 10) / ts_std(close, 10)
# [22/216] Evaluating: rank(ts_delta(close, 20) / close)
# [23/216] Evaluating: rank(close / ts_max(close, 60))
# [24/216] Evaluating: rank(close - ts_mean(close, 5)) - rank(close - ts_mean(close
# [25/216] Evaluating: ts_delta(close, 5) * rank(volume / adv20)
# [26/216] Evaluating: rank(ts_delta(close, 3) + ts_delta(close, 6) + ts_delta(clos
# [27/216] Evaluating: ts_delta(ts_delta(close, 5), 5)
# [28/216] Evaluating: rank(returns * volume)
# [29/216] Evaluating: rank(ts_mean(returns, 5)) - rank(ts_mean(returns, 20))
# [30/216] Evaluating: rank(close / ts_min(close, 20))
# [31/216] Evaluating: rank(vwap / ts_mean(vwap, 20))
# [32/216] Evaluating: ts_delta(close, 10) / (ts_max(close, 10) - ts_min(close, 10)
# [33/216] Evaluating: rank(ts_mean(returns, 3) / (ts_std(returns, 20) + 0.001))
# [34/216] Evaluating: rank(ts_delta(vwap, 10) / vwap)
# [35/216] Evaluating: sign(ts_delta(close, 5)) * rank(abs(ts_delta(close, 5)))
# [36/216] Evaluating: rank(close / ts_mean(close, 10)) * rank(close / ts_mean(clos
# [37/216] Evaluating: ts_mean(sign(returns), 10)
# [38/216] Evaluating: rank(ts_delta(high, 10))
# [39/216] Evaluating: rank((close - low) / (high - low + 0.001)) * rank(ts_delta(c
# [40/216] Evaluating: ts_delta(close, 20) / (ts_std(close, 60) + 0.001)
# [41/216] Evaluating: rank(ts_mean(close * volume, 5) / ts_mean(close * volume, 20
# [42/216] Evaluating: rank(ts_max(returns, 5))
# [43/216] Evaluating: ts_delta(rank(close), 10)
# [44/216] Evaluating: rank(ts_corr(rank(returns), rank(volume), 10))
# [45/216] Evaluating: rank(ts_delta(close, 5)) * sign(ts_delta(volume, 5))
# [46/216] Evaluating: zscore(ts_delta(close, 10)) + zscore(ts_delta(close, 20))
# [47/216] Evaluating: rank((close - ts_min(close, 20)) / (ts_max(close, 20) - ts_m
# [48/216] Evaluating: rank(ts_mean(returns * volume, 10) / (adv20 + 0.001))
# [49/216] Evaluating: ts_delta(ts_mean(close, 5), 5) / ts_std(close, 20)
# [50/216] Evaluating: rank(ts_delta(close, 40)) * rank(ts_delta(volume, 10))
# [51/216] Evaluating: rank(close / open) * rank(ts_delta(close, 10))
# [52/216] Evaluating: rank(ts_mean(high - low, 5) / ts_mean(high - low, 20))
# [53/216] Evaluating: ts_delta(close, 3) / (ts_max(high, 10) - ts_min(low, 10) + 0
# [54/216] Evaluating: rank(log(close) - log(ts_mean(close, 60)))
# [55/216] Evaluating: rank(ts_delta(close, 10)) - rank(ts_delta(close, 60))
# [56/216] Evaluating: zscore(ts_mean(returns, 5)) * zscore(ts_mean(volume, 5) / ad
# [57/216] Evaluating: rank(ts_mean(close / vwap, 10))
# [58/216] Evaluating: power(rank(ts_delta(close, 5)), 2) * sign(ts_delta(close, 5)
# [59/216] Evaluating: rank(ts_delta(close, 5) / close) - rank(ts_std(returns, 5))
# [60/216] Evaluating: rank(ts_delta(close, 10)) * rank(ts_mean(volume, 5) / ts_mea
# [61/216] Evaluating: ts_delta(rank(vwap), 5)
# [62/216] Evaluating: rank(ts_delta(high, 5) + ts_delta(low, 5))
# [63/216] Evaluating: rank(close - ts_mean(close, 10)) / (ts_std(close, 10) + 0.00
# [64/216] Evaluating: ts_mean(sign(returns) * rank(abs(returns)), 10)
# [65/216] Evaluating: rank(ts_delta(close, 5)) * rank(1 / (ts_std(returns, 10) + 0
# [66/216] Evaluating: rank(ts_mean(close, 5) / ts_mean(close, 20) - 1)
# [67/216] Evaluating: -1 * rank(ts_delta(close, 3) / close)
# [68/216] Evaluating: -1 * zscore(close / ts_mean(close, 10) - 1)
# [69/216] Evaluating: -1 * rank((close - ts_min(close, 20)) / (ts_max(close, 20) -
# [70/216] Evaluating: -1 * rank(close / vwap - 1)
# [71/216] Evaluating: rank(ts_mean(close, 60) / close - 1)
# [72/216] Evaluating: -1 * rank(ts_delta(close, 10) / ts_std(close, 20))
# [73/216] Evaluating: -1 * zscore(returns) * rank(volume / adv20)
# [74/216] Evaluating: rank(ts_mean(vwap, 20) / vwap - 1)
# [75/216] Evaluating: -1 * rank(ts_delta(close, 5)) * rank(ts_std(returns, 5))
# [76/216] Evaluating: -1 * rank((close - ts_mean(close, 20)) / ts_std(close, 20))
# [77/216] Evaluating: -1 * rank((close - ts_mean(close, 5)) / ts_std(close, 5))
# [78/216] Evaluating: -1 * sign(close - ts_mean(close, 10)) * rank(abs(close - ts_
# [79/216] Evaluating: rank(ts_mean(returns, 20)) * -1
# [80/216] Evaluating: -1 * rank(ts_mean(returns, 3))
# [81/216] Evaluating: rank(log(ts_mean(volume, 5)) - log(volume))
# [82/216] Evaluating: -1 * rank(close - open) * rank(abs(returns))
# [83/216] Evaluating: -1 * rank(ts_delta(vwap, 5) / ts_std(vwap, 20))
# [84/216] Evaluating: rank(ts_mean(close, 40) - close) / rank(ts_std(close, 40))
# [85/216] Evaluating: -1 * rank((high - low) / close) * sign(returns)
# [86/216] Evaluating: -1 * rank(ts_max(close, 10) / close - 1) * sign(ts_delta(clo
# [87/216] Evaluating: -1 * zscore(close / ts_mean(close, 20) - 1) * zscore(volume
# [88/216] Evaluating: rank(1 - close / ts_max(close, 60))
# [89/216] Evaluating: -1 * rank(ts_delta(close, 1) / ts_std(close, 10))
# [90/216] Evaluating: -1 * rank(power(returns, 3))
# [91/216] Evaluating: rank(ts_min(close, 10) / close - 1) * -1
# [92/216] Evaluating: -1 * rank(ts_corr(close, volume, 5)) * rank(abs(ts_delta(clo
# [93/216] Evaluating: rank(ts_mean(low, 10) / close - 1)
# [94/216] Evaluating: -1 * rank(ts_delta(close, 5) + ts_delta(close, 10))
# [95/216] Evaluating: -1 * zscore((high + low + close) / 3 / ts_mean((high + low +
# [96/216] Evaluating: rank(adv20 / volume) * sign(ts_mean(close, 10) - close)
# [97/216] Evaluating: -1 * rank(ts_delta(high, 5) / ts_std(high, 20))
# [98/216] Evaluating: -1 * rank((close - open) / (high - low + 0.0001))
# [99/216] Evaluating: -1 * rank(ts_mean(returns, 5)) * rank(ts_std(returns, 5))
# [100/216] Evaluating: rank(vwap / close - 1) * rank(volume / adv20)
# [101/216] Evaluating: -1 * rank(ts_delta(close / vwap, 5))
# [102/216] Evaluating: rank(ts_mean(open, 10) / open - 1)
# [103/216] Evaluating: -1 * rank(ts_delta(close, 20) / close) * rank(1 / ts_std(ret
# [104/216] Evaluating: rank(ts_corr(returns, volume, 10)) * -1
# [105/216] Evaluating: -1 * rank(ts_delta(ts_mean(close, 5), 5))
# [106/216] Evaluating: rank(ts_min(low, 20) / close - 1) * -1 + rank(1 - close / ts
# [107/216] Evaluating: -1 * zscore(ts_delta(close, 2)) * zscore(ts_delta(close, 2)
# [108/216] Evaluating: rank(ts_mean(volume, 20) / ts_mean(volume, 5) - 1) * sign(ts
# [109/216] Evaluating: -1 * rank(ts_mean(high / close - 1, 10))
# [110/216] Evaluating: -1 * rank(ts_delta(close, 5)) * rank(ts_delta(volume, 5) / a
# [111/216] Evaluating: rank(ts_corr(close, volume, 5))
# [112/216] Evaluating: rank(ts_corr(close, volume, 20)) - rank(ts_corr(close, volum
# [113/216] Evaluating: rank(ts_corr(abs(returns), volume, 10))
# [114/216] Evaluating: rank(ts_corr(vwap - close, volume, 10))
# [115/216] Evaluating: zscore(ts_mean(returns * volume, 10) / ts_mean(volume, 10))
# [116/216] Evaluating: rank(ts_mean(returns * (volume / adv20), 5))
# [117/216] Evaluating: rank(ts_delta(volume, 5) * ts_delta(close, 5))
# [118/216] Evaluating: -1 * rank(ts_delta(volume, 5) * ts_delta(close, 5)) * sign(t
# [119/216] Evaluating: rank(close / vwap)
# [120/216] Evaluating: rank(ts_mean(close / vwap, 5))
# [121/216] Evaluating: rank(ts_mean((close - vwap) * volume, 10))
# [122/216] Evaluating: rank(ts_mean((close - vwap) / vwap, 10)) * rank(volume / adv
# [123/216] Evaluating: zscore((close - vwap) / (high - low + 0.0001))
# [124/216] Evaluating: rank(ts_corr(vwap, volume, 15))
# [125/216] Evaluating: -1 * rank(ts_corr(rank(close), rank(volume), 10))
# [126/216] Evaluating: rank(ts_mean(volume * sign(returns), 20) / ts_mean(volume, 2
# [127/216] Evaluating: rank(ts_mean(volume * sign(returns), 10) / adv20)
# [128/216] Evaluating: rank(ts_mean(volume * returns, 10) / ts_std(volume * returns
# [129/216] Evaluating: rank(log(volume / adv20) * returns)
# [130/216] Evaluating: rank(ts_delta(close, 10)) * rank(ts_delta(volume, 10))
# [131/216] Evaluating: -1 * rank(ts_delta(close, 10)) * (1 - rank(ts_delta(volume,
# [132/216] Evaluating: rank(ts_std(volume, 10) / ts_mean(volume, 10)) * sign(ts_del
# [133/216] Evaluating: rank(ts_min(volume, 10) / ts_max(volume, 10)) * rank(returns
# [134/216] Evaluating: rank((close - ts_min(close, 20)) / (ts_max(close, 20) - ts_m
# [135/216] Evaluating: rank(ts_corr((high - low) / close, volume / adv20, 10))
# [136/216] Evaluating: -1 * rank(ts_corr(ts_mean(close, 5), ts_mean(volume, 5), 20)
# [137/216] Evaluating: rank(ts_mean((high - close) / (high - low + 0.0001) * volume
# [138/216] Evaluating: -1 * rank(ts_mean((close - low) / (high - low + 0.0001) * vo
# [139/216] Evaluating: zscore(ts_delta(volume / adv20, 5)) * sign(ts_delta(close, 5
# [140/216] Evaluating: rank(ts_corr(close, log(volume), 10)) - rank(ts_corr(close,
# [141/216] Evaluating: rank(ts_mean(abs(returns) / (volume / adv20 + 0.0001), 10))
# [142/216] Evaluating: -1 * rank(ts_mean(abs(returns) / (volume / adv20 + 0.0001),
# [143/216] Evaluating: rank(ts_corr(power(returns, 2), volume, 15))
# [144/216] Evaluating: rank(ts_mean(sign(returns) * log(volume / adv20 + 1), 20))
# [145/216] Evaluating: rank(ts_max(volume, 20) / adv20) * rank(ts_delta(close, 20))
# [146/216] Evaluating: -1 * rank(ts_max(volume, 10) / adv20) * rank(close / ts_max(
# [147/216] Evaluating: rank(ts_corr(low, volume, 10)) - rank(ts_corr(high, volume,
# [148/216] Evaluating: rank(ts_mean((vwap - open) / (open + 0.0001) * volume, 10))
# [149/216] Evaluating: zscore(ts_mean(returns * power(volume / adv20, 2), 10))
# [150/216] Evaluating: rank(ts_delta(ts_corr(close, volume, 10), 5))
# [151/216] Evaluating: rank(ts_std(returns * volume, 10) / (ts_std(returns, 10) * t
# [152/216] Evaluating: rank((close - vwap) / (ts_std(close, 20) + 0.0001)) * rank(v
# [153/216] Evaluating: -1 * rank(ts_mean(ts_delta(volume, 1) * ts_delta(close, 1),
# [154/216] Evaluating: rank(ts_std(returns, 5) / ts_std(returns, 60))
# [155/216] Evaluating: rank(-ts_std(returns, 20))
# [156/216] Evaluating: zscore(ts_mean(high - low, 5) / ts_mean(high - low, 60))
# [157/216] Evaluating: rank(ts_std(returns, 5)) * sign(ts_delta(close, 5))
# [158/216] Evaluating: rank(ts_delta(ts_std(returns, 20), 10))
# [159/216] Evaluating: rank(log(high / low))
# [160/216] Evaluating: rank(ts_mean(log(high / low), 10))
# [161/216] Evaluating: zscore(ts_std(volume, 10) / ts_mean(volume, 10))
# [162/216] Evaluating: rank(ts_std(returns, 10) - ts_std(returns, 60))
# [163/216] Evaluating: rank(ts_max(high, 20) - ts_min(low, 20)) / ts_mean(close, 20
# [164/216] Evaluating: -rank(ts_std(ts_std(returns, 10), 20))
# [165/216] Evaluating: rank(ts_corr(ts_std(returns, 5), volume, 20))
# [166/216] Evaluating: zscore(ts_mean(abs(returns), 10))
# [167/216] Evaluating: rank(ts_mean(abs(close - vwap), 10) / ts_mean(close, 10))
# [168/216] Evaluating: -rank(ts_std(returns, 5) / ts_mean(abs(returns), 5))
# [169/216] Evaluating: rank(ts_min(ts_std(returns, 10), 20))
# [170/216] Evaluating: zscore(ts_std(returns, 20)) * zscore(-ts_delta(close, 20) /
# [171/216] Evaluating: rank((high - low) / (ts_max(high, 10) - ts_min(low, 10) + 0.
# [172/216] Evaluating: rank(ts_corr(abs(returns), volume / adv20, 20))
# [173/216] Evaluating: zscore(ts_delta(ts_mean(high - low, 5), 5))
# [174/216] Evaluating: rank(ts_std(close / vwap, 20))
# [175/216] Evaluating: -rank(power(ts_std(returns, 20), 2))
# [176/216] Evaluating: rank(ts_mean(abs(returns), 5) / ts_mean(abs(returns), 60))
# [177/216] Evaluating: rank(ts_std(high - low, 10) / ts_mean(high - low, 10))
# [178/216] Evaluating: zscore(ts_max(returns, 20) - ts_min(returns, 20))
# [179/216] Evaluating: rank(ts_corr(ts_std(returns, 5), ts_delta(close, 5), 20))
# [180/216] Evaluating: -rank(ts_mean(power(returns, 2), 20))
# [181/216] Evaluating: rank((ts_max(high, 10) - close) / (ts_max(high, 10) - ts_min
# [182/216] Evaluating: zscore(ts_std(open - close, 10) / ts_mean(close, 10))
# [183/216] Evaluating: rank(ts_delta(log(high / low), 5))
# [184/216] Evaluating: rank(ts_std(returns, 10)) - rank(ts_std(returns, 60))
# [185/216] Evaluating: rank(ts_corr(high - low, volume, 20))
# [186/216] Evaluating: zscore(ts_mean(high - close, 10) / ts_mean(close - low, 10))
# [187/216] Evaluating: -rank(ts_max(abs(returns), 20))
# [188/216] Evaluating: rank(ts_std(returns, 10) * ts_mean(volume, 10) / adv20)
# [189/216] Evaluating: zscore(ts_min(low, 10) / ts_max(high, 10))
# [190/216] Evaluating: rank(ts_delta(ts_mean(abs(close - open), 5), 5))
# [191/216] Evaluating: rank(ts_corr(returns, ts_std(returns, 5), 20))
# [192/216] Evaluating: -zscore(ts_mean(high - low, 5) / close)
# [193/216] Evaluating: rank(ts_std(close - ts_mean(close, 5), 20))
# [194/216] Evaluating: rank(ts_std(volume, 20) / adv20) * sign(-ts_delta(ts_std(ret
# [195/216] Evaluating: zscore(ts_mean(high / low, 20)) * rank(-ts_std(returns, 20))
# [196/216] Evaluating: rank(ts_corr(ts_std(returns, 10), adv20, 20))
# [197/216] Evaluating: rank(ts_std(vwap / close, 20))
# [198/216] Evaluating: -rank(ts_mean(power(returns - ts_mean(returns, 20), 2), 20))
# [199/216] Evaluating: rank(ts_delta(vwap, 10) / ts_std(close, 20))
# [200/216] Evaluating: rank(ts_delta(ts_delta(close, 5), 5) / close)
# [201/216] Evaluating: rank((close - ts_min(close, 20)) / (ts_max(close, 20) - ts_m
# [202/216] Evaluating: rank(ts_mean(returns, 5)) - rank(ts_mean(returns, 60))
# [203/216] Evaluating: zscore(ts_mean(returns, 10)) * rank(ts_corr(close, volume, 1
# [204/216] Evaluating: -rank((close - ts_min(close, 10)) / (ts_max(close, 10) - ts_
# [205/216] Evaluating: rank((ts_mean(vwap, 10) - close) / close)
# [206/216] Evaluating: -rank(ts_delta(close, 3) / ts_std(close, 20)) * rank(volume
# [207/216] Evaluating: rank(ts_mean(close, 50) / close - 1) * rank(ts_std(returns,
# [208/216] Evaluating: rank(ts_mean(returns * (volume / adv20), 10))
# [209/216] Evaluating: rank(ts_delta(volume, 5) / adv20) * sign(-ts_delta(close, 5)
# [210/216] Evaluating: zscore((close - vwap) / close * log(volume / adv20 + 1))
# [211/216] Evaluating: rank(ts_mean((high - low) / vwap, 5) / ts_mean(volume / adv2
# [212/216] Evaluating: rank(-1 * ts_std(returns, 20))
# [213/216] Evaluating: zscore(ts_std(returns, 5) / ts_std(returns, 60))
# [214/216] Evaluating: rank(-1 * ts_mean((high - low) / close, 10))
# [215/216] Evaluating: rank(close / (ts_max(high, 20) - ts_min(low, 20)))
# [216/216] Evaluating: rank(ts_corr(abs(returns), volume / adv20, 15))
# Time for evaluate_all_factors: 190.80 seconds
#
# Factor ranking:
#                                                                                                                                                                                factor  IC_mean    ICIR  Sharpe     MDD  Turnover   score
# rank
# 1                                                                                                                                       rank(vwap / close - 1) * rank(volume / adv20)   0.0169  0.1420  1.0861 -0.1830    0.7077  0.7556
# 2                                                                                                                                         -1 * zscore(returns) * rank(volume / adv20)   0.0180  0.1111  1.3615 -0.1408    0.6850  0.7338
# 3                                                                                                        -rank((close - ts_min(close, 10)) / (ts_max(close, 10) - ts_min(close, 10)))   0.0145  0.0881  1.9927 -0.0730    0.5955  0.7303
# 4                                                                                                                                                        -1 * rank(power(returns, 3))   0.0179  0.1031  1.3031 -0.1682    0.7146  0.7250
# 5                                                                                                                                                                  rank(open / close)   0.0154  0.0962  1.4001 -0.1833    0.7119  0.7194
# 6                                                                                                                                   -1 * rank(ts_delta(close, 1) / ts_std(close, 10))   0.0168  0.1052  1.0751 -0.1915    0.7295  0.7092
# 7                                                                                                                                   -1 * rank((close - open) / (high - low + 0.0001))   0.0148  0.1006  1.2029 -0.1607    0.7889  0.6923
# 8                                                                                                                                     -1 * rank((high - low) / close) * sign(returns)   0.0148  0.0898  1.1474 -0.1745    0.5982  0.6910
# 9                                                                                                                                  -1 * rank(ts_delta(close, 10) / ts_std(close, 20))   0.0145  0.0871  1.1678 -0.1200    0.4292  0.6819
# 10                                                                                                                                       rank(ts_std(returns, 10) * (volume / adv20))   0.0133  0.0824  1.1734 -0.1343    0.4346  0.6756
# 11                                                                                                                          -1 * rank((close - ts_mean(close, 5)) / ts_std(close, 5))   0.0159  0.0973  0.9585 -0.1495    0.7481  0.6702
# 12                                                                                                                                    rank(ts_corr(abs(returns), volume / adv20, 15))   0.0083  0.0946  1.2013 -0.0822    0.2197  0.6696
# 13                                                                                                                                        -1 * zscore(close / ts_mean(close, 10) - 1)   0.0156  0.0860  0.8605 -0.1354    0.3406  0.6687
# 14                                                                                              -1 * sign(close - ts_mean(close, 10)) * rank(abs(close - ts_mean(close, 10)) / close)   0.0156  0.0860  0.8605 -0.1354    0.3406  0.6687
# 15                                                                                                                                          rank((ts_mean(vwap, 10) - close) / close)   0.0153  0.0848  0.8144 -0.1349    0.3345  0.6621
# 16                                                                                                                 rank(ts_mean((high - close) / (high - low + 0.0001) * volume, 10))   0.0054  0.0489  1.5503 -0.1320    0.0564  0.6580
# 17                                                                                                                                            rank(ts_corr(abs(returns), volume, 10))   0.0083  0.0958  1.1233 -0.0757    0.2953  0.6570
# 18                                                                                                                        -1 * rank((close - ts_mean(close, 20)) / ts_std(close, 20))   0.0139  0.0816  0.8370 -0.1475    0.3860  0.6547
# 19                                                                                                                             rank((ts_mean(close, 20) - close) / ts_std(close, 20))   0.0139  0.0816  0.8370 -0.1475    0.3860  0.6547
# 20                                                                                                                                       rank(ts_corr(power(returns, 2), volume, 15))   0.0080  0.0928  0.8617 -0.1202    0.2101  0.6487
# 21                                                                                                                                                 rank(ts_mean(low, 10) / close - 1)   0.0140  0.0780  0.7343 -0.1313    0.3339  0.6397
# 22                                                                                                  -1 * zscore((high + low + close) / 3 / ts_mean((high + low + close) / 3, 15) - 1)   0.0138  0.0748  0.6942 -0.1281    0.2403  0.6365
# 23                                                                                                                                               -1 * rank(ts_delta(close / vwap, 5))   0.0125  0.0809  0.9520 -0.1376    0.7199  0.6325
# 24                                                                                                                                -1 * rank(ts_delta(close, 5) + ts_delta(close, 10))   0.0116  0.0718  0.8542 -0.1152    0.2572  0.6323
# 25                                                                                                                                                  zscore(ts_mean(abs(returns), 10))   0.0087  0.0422  0.7862 -0.2658    0.2039  0.6290
# 26                                                                                                                                                 rank(ts_mean(vwap, 20) / vwap - 1)   0.0129  0.0700  0.6973 -0.1200    0.2054  0.6266
# 27                                                                                                                              zscore(ts_std(open - close, 10) / ts_mean(close, 10))   0.0084  0.0455  0.8836 -0.2213    0.1969  0.6266
# 28                                                                                                                            rank(ts_std(returns, 10) * ts_mean(volume, 10) / adv20)   0.0093  0.0518  0.7994 -0.2052    0.2004  0.6254
# 29                                                                                                                                                              rank(log(high / low))   0.0093  0.0537  1.0879 -0.2084    0.6922  0.6215
# 30                                                                                                                                                        -1 * rank(close / vwap - 1)   0.0114  0.0734  0.8321 -0.1716    0.7041  0.6197
# 31                                                                                                                                                 rank(ts_mean(log(high / low), 10))   0.0073  0.0327  0.8123 -0.2606    0.1288  0.6167
# 32                                                                                                    rank((ts_max(high, 10) - close) / (ts_max(high, 10) - ts_min(low, 10) + 0.001))   0.0128  0.0772  0.7163 -0.1311    0.5597  0.6167
# 33                                                                                                            -1 * rank(ts_max(volume, 10) / adv20) * rank(close / ts_max(close, 10))   0.0097  0.0737  0.7700 -0.1284    0.3565  0.6166
# 34                                                                                                                                              -1 * rank(ts_delta(close, 3) / close)   0.0124  0.0683  0.7558 -0.1452    0.4957  0.6162
# 35                                                                                                                                                     -1 * rank(ts_mean(returns, 3))   0.0124  0.0682  0.7358 -0.1403    0.4952  0.6128
# 36                                                                                                                                            rank(ts_corr(returns, volume, 10)) * -1   0.0103  0.0895  0.2999 -0.1490    0.2737  0.6094
# 37                                                                                                                        rank(ts_mean(abs(returns) / (volume / adv20 + 0.0001), 10))   0.0056  0.0264  0.7525 -0.3057    0.1924  0.6066
# 38                                                                                                                  -1 * rank(ts_delta(close, 10)) * (1 - rank(ts_delta(volume, 10)))   0.0090  0.0729  0.8274 -0.1146    0.4723  0.6055
# 39                                                                                                                                   rank(ts_mean(returns, 20) - ts_mean(returns, 5))   0.0111  0.0646  0.6299 -0.1552    0.3913  0.6050
# 40                                                                                                                          rank(ts_mean(abs(close - vwap), 10) / ts_mean(close, 10))   0.0071  0.0376  0.8354 -0.2140    0.2059  0.6038
# 41                                                                                                                                  zscore(ts_max(returns, 20) - ts_min(returns, 20))   0.0059  0.0308  0.5879 -0.2976    0.1016  0.6022
# 42                                                                                           rank(ts_std(returns * volume, 10) / (ts_std(returns, 10) * ts_std(volume, 10) + 0.0001))   0.0043  0.0616  1.0625 -0.0963    0.2615  0.6004
# 43                                                                                                            rank((ts_max(high, 20) - close) / (ts_max(high, 20) - ts_min(low, 20)))   0.0117  0.0699  0.5164 -0.1476    0.4537  0.5975
# 44                                                                                                                                    rank(ts_corr(abs(returns), volume / adv20, 20))   0.0056  0.0634  0.7789 -0.1198    0.1758  0.5963
# 45                                                                                                                                              rank(ts_min(ts_std(returns, 10), 20))   0.0052  0.0243  0.7543 -0.2573    0.0665  0.5952
# 46                                                                                                                                          -1 * rank(ts_delta(ts_mean(close, 5), 5))   0.0089  0.0555  0.7352 -0.1138    0.1939  0.5934
# 47                                                                                                                                            rank(ts_delta(ts_std(returns, 20), 10))   0.0063  0.0555  0.8255 -0.1201    0.2072  0.5915
# 48                                                                                                                 rank(ts_mean((high - low) / vwap, 5) / ts_mean(volume / adv20, 5))   0.0044  0.0218  0.9221 -0.2493    0.2111  0.5913
# 49                                                                                                               -1 * rank(ts_max(close, 10) / close - 1) * sign(ts_delta(close, 10))   0.0090  0.0595  0.7801 -0.1068    0.3638  0.5892
# 50                                                                                                                                               rank(ts_std(ts_std(returns, 5), 20))   0.0060  0.0377  0.7688 -0.1701    0.0965  0.5864
# 51                                                                                                   -1 * rank((close - ts_min(close, 20)) / (ts_max(close, 20) - ts_min(close, 20)))   0.0134  0.0800 -0.0799 -0.2198    0.4742  0.5863
# 52                                                                                                             -1 * rank(ts_delta(close, 20) / close) * rank(1 / ts_std(returns, 20))   0.0080  0.0412  0.6208 -0.1803    0.1630  0.5850
# 53                                                                                                                                                     rank(ts_std(vwap / close, 20))   0.0042  0.0202  0.5724 -0.3011    0.1069  0.5810
# 54                                                                                                                                                     rank(ts_std(close / vwap, 20))   0.0042  0.0201  0.5836 -0.2971    0.1073  0.5805
# 55                                                                                                                                       rank(ts_std(close / ts_mean(close, 10), 20))   0.0041  0.0213  0.7659 -0.2419    0.1076  0.5800
# 56                                                                                                                   rank(ts_mean(close, 50) / close - 1) * rank(ts_std(returns, 10))   0.0080  0.0414  0.6946 -0.1418    0.1929  0.5774
# 57                                                                                                                                    -1 * rank(ts_delta(vwap, 5) / ts_std(vwap, 20))   0.0094  0.0566  0.3366 -0.1843    0.3985  0.5705
# 58                                                                                                                                                 rank(ts_mean(open, 10) / open - 1)   0.0091  0.0503  0.4760 -0.1596    0.3492  0.5690
# 59                                                                                                                   -1 * rank(ts_mean(ts_delta(volume, 1) * ts_delta(close, 1), 10))   0.0083  0.0690  0.0222 -0.1779    0.1515  0.5679
# 60                                                                                                                                      rank(ts_corr(ts_std(returns, 5), volume, 20))   0.0039  0.0521  0.7089 -0.0941    0.1882  0.5594
# 61                                                                                                                            rank(ts_corr((high - low) / close, volume / adv20, 10))   0.0034  0.0431  0.9089 -0.1002    0.3035  0.5580
# 62                                                                                                                                        rank(ts_std(close - ts_mean(close, 5), 20))   0.0064  0.0448  0.3555 -0.1515    0.0441  0.5577
# 63                                                                                                                      rank(ts_delta(volume, 5) / adv20) * sign(-ts_delta(close, 5))   0.0096  0.0745  0.1582 -0.1552    0.5855  0.5560
# 64                                                                                                                           zscore(ts_mean(high - low, 5) / ts_mean(high - low, 60))   0.0049  0.0449  0.1706 -0.2700    0.3330  0.5540
# 65                                                                                                                                       -1 * rank(close - open) * rank(abs(returns))   0.0072  0.0572  0.5893 -0.1491    0.7092  0.5521
# 66                                                                                                        rank(ts_min(low, 20) / close - 1) * -1 + rank(1 - close / ts_max(high, 20))   0.0040  0.0217  0.4657 -0.2606    0.2692  0.5485
# 67                                                                                                                                                 rank(ts_delta(log(high / low), 5))   0.0071  0.0610  0.3585 -0.1867    0.7252  0.5470
# 68                                                                                                                       zscore(ts_mean(high / low, 20)) * rank(-ts_std(returns, 20))   0.0039  0.0176  0.1411 -0.3183    0.1122  0.5432
# 69                                                                                                                                                    rank(ts_mean(returns, 20)) * -1   0.0075  0.0402  0.2382 -0.1666    0.1977  0.5407
# 70                                                                                                                                              rank(ts_corr(high - low, volume, 20))   0.0026  0.0304  0.6095 -0.1550    0.1761  0.5383
# 71                                                                                                                               rank(ts_delta(close, 5)) * sign(ts_delta(volume, 5))   0.0050  0.0588  0.3139 -0.1221    0.3794  0.5336
# 72                                                                                                                                                rank(1 - close / ts_max(close, 60))   0.0055  0.0281  0.4881 -0.1445    0.2556  0.5282
# 73                                                                                                                             rank(ts_mean(high - low, 5) / ts_mean(high - low, 20))   0.0042  0.0407  0.1853 -0.2157    0.3591  0.5276
# 74                                                                                                                                      rank(ts_corr(ts_std(returns, 10), adv20, 20))   0.0030  0.0437  0.4382 -0.1057    0.1708  0.5258
# 75                                                                                                                 rank(ts_corr(close, volume, 20)) - rank(ts_corr(close, volume, 5))   0.0044  0.0499  0.5233 -0.0945    0.4483  0.5249
# 76                                                                                                                      rank(ts_max(high, 20) - ts_min(low, 20)) / ts_mean(close, 20)   0.0009  0.0060  0.8430 -0.1426    0.0863  0.5232
# 77                                                                                                                                    rank(ts_std(returns, 10) - ts_std(returns, 60))   0.0019  0.0154  0.6478 -0.1532    0.1787  0.5191
# 78                                                                                                                                    -1 * rank(ts_delta(high, 5) / ts_std(high, 20))   0.0066  0.0406  0.2154 -0.1462    0.4226  0.5137
# 79                                                                                                                            rank(adv20 / volume) * sign(ts_mean(close, 10) - close)   0.0061  0.0539  0.1227 -0.1418    0.5492  0.5101
# 80                                                                                                                    rank(ts_mean((close - vwap) / vwap, 10)) * rank(volume / adv20)   0.0058  0.0508  0.2530 -0.1146    0.5149  0.5100
# 81                                                                                                                                        zscore(ts_delta(ts_mean(high - low, 5), 5))   0.0029  0.0299  0.0833 -0.2322    0.3158  0.5077
# 82                                                                                                                             rank(ts_std(high - low, 10) / ts_mean(high - low, 10))   0.0024  0.0256  0.4272 -0.1467    0.2568  0.5070
# 83                                                                                                                              rank(ts_std(returns, 10)) - rank(ts_std(returns, 60))   0.0023  0.0208  0.5144 -0.1324    0.2140  0.5066
# 84                                                                                                                     rank(ts_mean(close * volume, 5) / ts_mean(close * volume, 20))   0.0038  0.0520 -0.1263 -0.1730    0.2624  0.5050
# 85                                                                                                                                  -1 * rank(ts_corr(rank(close), rank(volume), 10))   0.0031  0.0455  0.2793 -0.0952    0.3233  0.5007
# 86                                                                                                                                       rank((high - low) / ts_mean(high - low, 20))   0.0041  0.0402  0.2784 -0.1770    0.7791  0.4941
# 87                                                                                                                                            rank(ts_corr(vwap - close, volume, 10))   0.0041  0.0445  0.0236 -0.1191    0.3037  0.4900
# 88                                                                                                                           -1 * rank(ts_delta(close, 5)) * rank(ts_std(returns, 5))   0.0037  0.0255  0.1821 -0.1689    0.3744  0.4899
# 89                                                                                                                                   rank(ts_delta(ts_mean(abs(close - open), 5), 5))   0.0022  0.0222 -0.1028 -0.2447    0.3431  0.4806
# 90                                                                                                                         rank(ts_mean(abs(returns), 5) / ts_mean(abs(returns), 60))   0.0017  0.0166  0.1527 -0.2081    0.3885  0.4793
# 91                                                                                                                                                           rank(ts_max(returns, 5))  -0.0017 -0.0107  0.2571 -0.3041    0.3151  0.4758
# 92                                                                                                                                        rank(ts_mean(volume, 5) / ts_std(close, 5))  -0.0009 -0.0081  0.8406 -0.0769    0.1327  0.4731
# 93                                                                                                                          -1 * rank(ts_mean(returns, 5)) * rank(ts_std(returns, 5))   0.0034  0.0223  0.0859 -0.1604    0.3948  0.4719
# 94                                                                                                                                   zscore(ts_std(returns, 5) / ts_std(returns, 60))   0.0017  0.0168 -0.1395 -0.2599    0.3712  0.4715
# 95                                                                                                                                     rank(ts_std(returns, 5) / ts_std(returns, 60))   0.0017  0.0168 -0.1395 -0.2599    0.3712  0.4715
# 96                                                                                                               -1 * zscore(close / ts_mean(close, 20) - 1) * zscore(volume / adv20)   0.0021  0.0319  0.2610 -0.1097    0.5046  0.4702
# 97                                                                                                                                               rank(ts_mean(close, 60) / close - 1)   0.0017  0.0084  0.0688 -0.1801    0.1323  0.4696
# 98                                                                                                                                     rank(ts_std(returns, 5) / ts_std(returns, 20))   0.0020  0.0195 -0.2211 -0.2540    0.3883  0.4658
# 99                                                                                                                                         rank(log(close) - log(ts_mean(close, 60)))  -0.0017 -0.0084 -0.0688 -0.2563    0.1323  0.4464
# 100                                                                                                                            rank(ts_delta(close, 40)) * rank(ts_delta(volume, 10))   0.0010  0.0078  0.0838 -0.1699    0.4342  0.4437
# 101                                                                                                                      zscore(ts_mean(high - close, 10) / ts_mean(close - low, 10))   0.0012  0.0084 -0.0741 -0.1840    0.3154  0.4437
# 102                                                                                                                 -1 * rank(ts_delta(close, 5)) * rank(ts_delta(volume, 5) / adv20)   0.0025  0.0222  0.0288 -0.1251    0.5602  0.4403
# 103                                                                                                 -1 * zscore(ts_delta(close, 2)) * zscore(ts_delta(close, 2) - ts_delta(close, 5))   0.0012  0.0166 -0.0777 -0.1484    0.3758  0.4381
# 104                                                                                                                                            -rank(ts_std(ts_std(returns, 10), 20))  -0.0001 -0.0009 -0.7825 -0.3621    0.0944  0.4359
# 105                                                                                                                              rank(log(volume / adv20) * sign(ts_delta(close, 5)))  -0.0004 -0.0044  0.5519 -0.1154    0.6365  0.4328
# 106                                                                                                                                rank(close / (ts_max(high, 20) - ts_min(low, 20)))  -0.0045 -0.0226 -0.6566 -0.4587    0.1255  0.4303
# 107                                                                                                                      -rank(ts_mean(power(returns - ts_mean(returns, 20), 2), 20))  -0.0052 -0.0240 -0.6004 -0.4426    0.1039  0.4268
# 108                                                                                                      -1 * rank(ts_corr(close, volume, 5)) * rank(abs(ts_delta(close, 5)) / close)   0.0031  0.0284 -0.4858 -0.1972    0.6052  0.4251
# 109                                                                                                              -rank(ts_delta(close, 3) / ts_std(close, 20)) * rank(volume / adv20)   0.0007  0.0057  0.2087 -0.1197    0.6067  0.4230
# 110                                                                                                                                                        rank(-ts_std(returns, 20))  -0.0057 -0.0268 -0.7279 -0.4794    0.1084  0.4214
# 111                                                                                                                                                    rank(-1 * ts_std(returns, 20))  -0.0057 -0.0268 -0.7279 -0.4794    0.1084  0.4214
# 112                                                                                                                                              -rank(power(ts_std(returns, 20), 2))  -0.0057 -0.0268 -0.7279 -0.4794    0.1084  0.4214
# 113                                                                                                                                             -rank(ts_mean(power(returns, 2), 20))  -0.0059 -0.0275 -0.6895 -0.4697    0.1063  0.4201
# 114                                                                                                    -1 * rank(ts_delta(volume, 5) * ts_delta(close, 5)) * sign(ts_delta(close, 5))   0.0009  0.0071 -0.4627 -0.2709    0.6008  0.4152
# 115                                                                                                                         rank(ts_corr(ts_std(returns, 5), ts_delta(close, 5), 20))  -0.0016 -0.0152  0.1107 -0.1329    0.1270  0.4147
# 116                                                                                                                  -1 * rank(ts_mean(abs(returns) / (volume / adv20 + 0.0001), 10))  -0.0056 -0.0264 -0.7525 -0.4669    0.1924  0.4104
# 117                                                                                                                                      rank(-1 * ts_mean((high - low) / close, 10))  -0.0073 -0.0328 -0.8063 -0.5095    0.1286  0.4084
# 118                                                                                                                  zscore(ts_mean(returns, 5)) * zscore(ts_mean(volume, 5) / adv20)  -0.0003 -0.0050 -0.0849 -0.1608    0.3735  0.4081
# 119                                                                                                                        rank(ts_mean(close, 40) - close) / rank(ts_std(close, 40))  -0.0020 -0.0125 -0.0036 -0.1221    0.0867  0.4054
# 120                                                                                                        rank((close - vwap) / (ts_std(close, 20) + 0.0001)) * rank(volume / adv20)   0.0013  0.0126 -0.2013 -0.1605    0.7089  0.4041
# 121                                                                                                                                  zscore(ts_std(volume, 10) / ts_mean(volume, 10))  -0.0006 -0.0087 -0.0322 -0.1192    0.2420  0.4022
# 122                                                                                                                                        rank(ts_mean((close - vwap) * volume, 10))  -0.0025 -0.0186 -0.3678 -0.2606    0.2018  0.4003
# 123                                                                                                     rank(ts_corr(close, log(volume), 10)) - rank(ts_corr(close, log(volume), 30))  -0.0014 -0.0147 -0.0123 -0.1433    0.2898  0.3976
# 124                                                                                                                     -1 * rank(ts_corr(ts_mean(close, 5), ts_mean(volume, 5), 20))  -0.0011 -0.0105 -0.3886 -0.1982    0.1669  0.3967
# 125                                                                                                                                                   rank(ts_corr(vwap, volume, 15))  -0.0029 -0.0269  0.2672 -0.1183    0.2502  0.3953
# 126                                                                                                                zscore(ts_std(returns, 20)) * zscore(-ts_delta(close, 20) / close)  -0.0016 -0.0243 -0.0097 -0.1507    0.1723  0.3952
# 127                                                                                                                                                   rank(ts_mean(close / vwap, 10))  -0.0028 -0.0190 -0.2055 -0.2143    0.2895  0.3920
# 128                                                                                                                                                   rank(close / ts_max(close, 60))  -0.0055 -0.0281 -0.4881 -0.3511    0.2556  0.3905
# 129                                                                                                                                                    rank(ts_mean(close / vwap, 5))  -0.0033 -0.0222 -0.4011 -0.2942    0.4034  0.3867
# 130                                                                                                                                                   -rank(ts_max(abs(returns), 20))  -0.0059 -0.0329 -0.7440 -0.3969    0.0915  0.3858
# 131                                                                                                                                                     rank(close - ts_min(low, 20))  -0.0023 -0.0148 -0.4717 -0.2321    0.2265  0.3857
# 132                                                                                                                                    rank(ts_corr(returns, ts_std(returns, 5), 20))  -0.0025 -0.0254 -0.3172 -0.2253    0.2400  0.3822
# 133                                                                                                                                        zscore(ts_min(low, 10) / ts_max(high, 10))  -0.0079 -0.0416 -0.6675 -0.4382    0.2053  0.3789
# 134                                                                                                                                          -1 * rank(ts_mean(high / close - 1, 10))  -0.0081 -0.0392 -0.6029 -0.4109    0.1936  0.3787
# 135                                                                                                                     power(rank(ts_delta(close, 5)), 2) * sign(ts_delta(close, 5))  -0.0040 -0.0286  0.2127 -0.1550    0.5029  0.3786
# 136                                                                                                                              -rank(ts_std(returns, 5) / ts_mean(abs(returns), 5))  -0.0032 -0.0348  0.2907 -0.1450    0.5183  0.3769
# ...
# 149                                                                                                                                                   rank(close / ts_min(close, 20))  -0.0110 -0.0639 -0.0682 -0.2799    0.3111  0.3326
# 150                                                                                                               rank(close / ts_mean(close, 10)) * rank(close / ts_mean(close, 40))  -0.0115 -0.0615 -0.4892 -0.3851    0.2785  0.3322
# 151                                                                                                                                                   rank(ts_delta(vwap, 10) / vwap)  -0.0117 -0.0629 -0.5378 -0.3976    0.2440  0.3317
# 152                                                                                                                                                    rank(ts_mean(close - open, 5))  -0.0070 -0.0481 -0.6829 -0.3297    0.3223  0.3302
# 153                                                                                                                rank(close - ts_mean(close, 5)) - rank(close - ts_mean(close, 40))  -0.0069 -0.0429 -0.2619 -0.2092    0.4244  0.3287
# 154                                                                                                                                                          rank(ts_delta(high, 10))  -0.0081 -0.0499 -0.7920 -0.3550    0.2198  0.3285
# 155                                                                                                                                      rank(ts_mean(close, 5) - ts_mean(close, 20))  -0.0087 -0.0528 -0.5004 -0.2691    0.1139  0.3276
# 156                                                                                                                                 ts_delta(close, 20) / (ts_std(close, 60) + 0.001)  -0.0085 -0.0517 -0.1507 -0.1920    0.2487  0.3270
# 157                                                                                                                                    rank(ts_delta(volume, 5) * ts_delta(close, 5))  -0.0051 -0.0537 -0.2029 -0.2084    0.4656  0.3251
# 158                                                                                                                       zscore(ts_mean(returns * volume, 10) / ts_mean(volume, 10))  -0.0118 -0.0688 -0.6224 -0.4206    0.2329  0.3245
# 159                                                                                                                                     rank(ts_mean(returns * (volume / adv20), 10))  -0.0114 -0.0673 -0.6173 -0.4035    0.2191  0.3239
# 160                                                                                                                               rank(ts_std(returns, 5)) * sign(ts_delta(close, 5))  -0.0104 -0.0673 -0.1164 -0.2611    0.2928  0.3217
# 161                                                                                                                                     rank(ts_delta(ts_delta(close, 5), 5) / close)  -0.0084 -0.0505 -0.4150 -0.2816    0.4451  0.3212
# 162                                                                                                                             rank(ts_mean(returns * volume, 10) / (adv20 + 0.001))  -0.0116 -0.0683 -0.6441 -0.4064    0.2242  0.3200
# 163                                                                                                                                        rank(ts_delta(high, 5) + ts_delta(low, 5))  -0.0088 -0.0554 -0.5039 -0.2870    0.2908  0.3175
# 164                                                                                                                            rank(ts_mean(returns, 5)) - rank(ts_mean(returns, 60))  -0.0102 -0.0584 -0.1888 -0.2341    0.3355  0.3157
# 165                                                                                                                                                    rank(vwap / ts_mean(vwap, 20))  -0.0129 -0.0700 -0.6973 -0.4227    0.2054  0.3141
# 166                                                                                                                                       rank(ts_delta(vwap, 10) * (volume / adv20))  -0.0093 -0.0571 -0.7431 -0.3474    0.2535  0.3140
# 167                                                                                                            -1 * rank(ts_mean((close - low) / (high - low + 0.0001) * volume, 10))  -0.0049 -0.0466 -1.3720 -0.3790    0.0532  0.3136
# 168                                                                                                                                                         ts_delta(rank(close), 10)  -0.0114 -0.0687 -0.7751 -0.4298    0.2998  0.3112
# 169                                                                                                                        rank(ts_corr(ts_delta(close, 1), ts_delta(volume, 1), 20))  -0.0074 -0.0669 -0.0282 -0.1345    0.1559  0.3111
# 170                                                                                                                                                        ts_mean(sign(returns), 10)  -0.0085 -0.0592 -0.4760 -0.2767    0.3335  0.3103
# 171                                                                                                                         zscore(ts_delta(close, 10)) + zscore(ts_delta(close, 20))  -0.0096 -0.0582 -0.5631 -0.2736    0.1909  0.3077
# 172                                                                                                                            rank(ts_delta(close, 10)) * rank(ts_delta(volume, 10))  -0.0068 -0.0560 -0.5321 -0.2749    0.4616  0.3074
# 173                                                                                                                                   ts_mean(sign(returns) * rank(abs(returns)), 10)  -0.0117 -0.0681 -0.6785 -0.3980    0.3239  0.3074
# 174                                                                                                                                      rank(ts_mean(returns * (volume / adv20), 5))  -0.0125 -0.0731 -0.6185 -0.4056    0.3301  0.3050
# 175                                                                                                                                                           ts_delta(rank(vwap), 5)  -0.0113 -0.0727 -0.5690 -0.3829    0.3707  0.3050
# 176                                                                                                                      rank(ts_max(volume, 20) / adv20) * rank(ts_delta(close, 20))  -0.0059 -0.0511 -0.8889 -0.2623    0.1943  0.2995
# 177                                                                                                                           zscore(ts_mean(returns * power(volume / adv20, 2), 10))  -0.0120 -0.0775 -0.5682 -0.3513    0.1828  0.2984
# 178                                                                                                                       rank(ts_mean((vwap - open) / (open + 0.0001) * volume, 10))  -0.0115 -0.0771 -0.5877 -0.3444    0.1819  0.2971
# 179                                                                                                                                                                rank(close / vwap)  -0.0114 -0.0734 -0.8321 -0.4999    0.7041  0.2958
# 180                                                                                                                                ts_delta(ts_mean(close, 5), 5) / ts_std(close, 20)  -0.0105 -0.0645 -0.5823 -0.2998    0.3029  0.2952
# 181                                                                                                                                                           rank(returns * volume)   -0.0124 -0.0801 -0.6151 -0.4318    0.4850  0.2951
# 182                                                                                                                          zscore((close - vwap) / close * log(volume / adv20 + 1))  -0.0113 -0.0748 -0.9847 -0.5357    0.6869  0.2936
# 183                                                                                                                  rank(ts_corr(low, volume, 10)) - rank(ts_corr(high, volume, 10))  -0.0029 -0.0376 -1.0992 -0.2325    0.3511  0.2903
# 184                                                                                                                                         ts_delta(close, 5) * rank(volume / adv20)  -0.0109 -0.0708 -0.6297 -0.3387    0.3919  0.2879
# 185                                                                                                                          sign(ts_delta(close, 5)) * rank(abs(ts_delta(close, 5)))  -0.0110 -0.0694 -0.6213 -0.3172    0.3230  0.2877
# 186                                                                                                                                                   ts_delta(ts_delta(close, 5), 5)  -0.0088 -0.0612 -0.4361 -0.2089    0.3600  0.2863
# 187                                                                                                                 ts_delta(close, 3) / (ts_max(high, 10) - ts_min(low, 10) + 0.001)  -0.0113 -0.0651 -0.5951 -0.3356    0.5780  0.2830
# 188                                                                                                                             rank(ts_delta(close, 10)) - rank(ts_delta(close, 60))  -0.0120 -0.0726 -0.5685 -0.2980    0.2612  0.2820
# 189                                                                                                                         rank(ts_mean(returns, 3) / (ts_std(returns, 20) + 0.001))  -0.0117 -0.0670 -0.7387 -0.3695    0.5294  0.2803
# 190                                                                                                         rank(ts_std(volume, 10) / ts_mean(volume, 10)) * sign(ts_delta(close, 5))  -0.0092 -0.0752 -0.3450 -0.2013    0.2534  0.2798
# 191                                                                                                                    zscore(ts_delta(volume / adv20, 5)) * sign(ts_delta(close, 5))  -0.0047 -0.0755 -0.3210 -0.2152    0.6627  0.2778
# 192                                                                                                                rank(ts_delta(close, 5)) * rank(1 / (ts_std(returns, 10) + 0.001))  -0.0131 -0.0755 -1.2348 -0.5025    0.3039  0.2777
# 193                                                                                                                                    rank(ts_corr(rank(returns), rank(volume), 10))  -0.0062 -0.0820 -0.4146 -0.2156    0.3312  0.2773
# 194                                                                                                                                          rank(ts_min(close, 10) / close - 1) * -1  -0.0124 -0.0735 -0.3959 -0.2727    0.4003  0.2770
# 195                                                                                                                       rank(ts_delta(close, 5) / close) - rank(ts_std(returns, 5))  -0.0140 -0.0811 -0.7772 -0.4222    0.3832  0.2762
# 196                                                                                                                                 rank(ts_mean(volume * sign(returns), 10) / adv20)  -0.0108 -0.0751 -0.7267 -0.3248    0.3081  0.2754
# 197                                                                                                     rank(ts_mean(volume, 20) / ts_mean(volume, 5) - 1) * sign(ts_delta(close, 5))  -0.0088 -0.0760 -0.2200 -0.1621    0.3086  0.2752
# 198                                                                                                                                        rank(ts_corr(returns, volume / adv20, 10))  -0.0109 -0.0927 -0.3371 -0.2565    0.2756  0.2677
# 199                                                                                                                                           rank((close - vwap) * (volume / adv20))  -0.0096 -0.0718 -1.0343 -0.3998    0.5388  0.2661
# 200                                                                                                                                                   rank(ts_corr(close, volume, 5))  -0.0074 -0.0743 -0.5908 -0.2554    0.5491  0.2644
# 201                                                                                                               rank(ts_delta(close, 3) + ts_delta(close, 6) + ts_delta(close, 12))  -0.0130 -0.0790 -0.8836 -0.3679    0.2680  0.2638
# 202                                                                                                             ts_delta(close, 10) / (ts_max(close, 10) - ts_min(close, 10) + 0.001)  -0.0125 -0.0734 -0.6223 -0.3250    0.5487  0.2635
# 203                                                                                                       rank((close - ts_min(close, 20)) / (ts_max(close, 20) - ts_min(close, 20)))  -0.0134 -0.0800  0.0799 -0.1467    0.4742  0.2612
# 204                                                                                                                                               rank(log(volume / adv20) * returns)  -0.0079 -0.0782 -0.8835 -0.3760    0.7023  0.2601
# 205                                                                                                                                           ts_delta(close, 10) / ts_std(close, 10)  -0.0130 -0.0769 -0.6502 -0.3295    0.5280  0.2573
# 206                                                                                                                     rank(ts_min(volume, 10) / ts_max(volume, 10)) * rank(returns)  -0.0101 -0.0778 -0.9407 -0.3917    0.6473  0.2549
# 207                                                                                               rank((close - ts_min(close, 20)) / (ts_max(close, 20) - ts_min(close, 20) + 0.001))  -0.0134 -0.0805 -0.3668 -0.2442    0.4657  0.2529
# 208                                                                                                                rank(ts_mean(volume * returns, 10) / ts_std(volume * returns, 10))  -0.0141 -0.0857 -0.8810 -0.3792    0.3205  0.2510
# 209                                                                                                                                      rank(ts_delta(vwap, 10) / ts_std(close, 20))  -0.0141 -0.0842 -1.1714 -0.4537    0.3788  0.2473
# 210                                                                                                                    rank(close - ts_mean(close, 10)) / (ts_std(close, 10) + 0.001)  -0.0127 -0.0908 -0.5262 -0.2032    0.2195  0.2320
# 211                                                                                                                                    zscore((close - vwap) / (high - low + 0.0001))  -0.0111 -0.0820 -1.1112 -0.4194    0.7872  0.2297
# 212                                                                                                             rank((close - low) / (high - low + 0.001)) * rank(ts_delta(close, 5))  -0.0138 -0.0975 -1.1469 -0.4192    0.6755  0.2029
# 213                                                                                                                                    rank(close / open) * rank(ts_delta(close, 10))  -0.0171 -0.1096 -1.2060 -0.5024    0.6373  0.1979
# 214                                                                                                               rank(-ts_corr(ts_delta(close, 5), ts_mean(volume, 5) - volume, 10))  -0.0110 -0.1127 -1.2851 -0.3634    0.3544  0.1869
# 215   rank((close - ts_min(close, 20)) / (ts_max(close, 20) - ts_min(close, 20) + 0.0001)) - rank((volume - ts_min(volume, 20)) / (ts_max(volume, 20) - ts_min(volume, 20) + 0.0001))  -0.0165 -0.1269 -1.3314 -0.4379    0.5467  0.1527
# 216                                                                                                                                       rank(log(ts_mean(volume, 5)) - log(volume))  -0.0096 -0.1364 -0.9703 -0.2692    0.7047  0.1371
#
# Saved to ../results/evaluation/factor_evaluation.csv

# %% [markdown]
# ## Part 5: PLotting results

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

def plot_score_ranking(results):
    fig, ax = plt.subplots(figsize=(12, 6))
 
    colors = ["blue" if s > 0.5 else "red" for s in results["score"]]
    labels = [f[:40] + "..." if len(f) > 40 else f for f in results["factor"]]
 
    ax.barh(range(len(results)), results["score"], color=colors)
    ax.set_yticks(range(len(results)))
    ax.set_yticklabels([f"#{i+1} {l}" for i, l in enumerate(labels)], fontsize=8)
    ax.axvline(0.5, color="gray", linewidth=0.8, linestyle="--", alpha=0.6)
    ax.set_xlabel("Composite Score")
    ax.set_title("Factor Ranking by Composite Score")
    ax.invert_yaxis()
 
    plt.tight_layout()
    plt.savefig("../results/plots/plot1_ranking.png", dpi=150, bbox_inches="tight")
    print("Saved: ../results/plots/plot1_ranking.png")
    plt.show()
    plt.close()
 
 
# ── Plot 2: ICIR vs Sharpe scatter ────────────────────────────────────────────
 
def plot_icir_vs_sharpe(results):
    fig, ax = plt.subplots(figsize=(10, 7))
 
    scatter = ax.scatter(
        results["ICIR"],
        results["Sharpe"],
        c=results["score"],
        cmap="RdYlGn",
        s=100,
        alpha=0.8,
        edgecolors="white",
        linewidths=0.5,
    )
 
    # Label top 5
    for _, row in results.head(5).iterrows():
        label = row["factor"][:30] + "..."
        ax.annotate(label, xy=(row["ICIR"], row["Sharpe"]),
                    xytext=(6, 4), textcoords="offset points", fontsize=7)
 
    ax.axhline(0, color="gray", linewidth=0.8, linestyle="--", alpha=0.5)
    ax.axvline(0, color="gray", linewidth=0.8, linestyle="--", alpha=0.5)
    ax.set_xlabel("ICIR (signal stability)")
    ax.set_ylabel("Sharpe (risk-adjusted return)")
    ax.set_title("ICIR vs Sharpe — top-right is best")
    plt.colorbar(scatter, ax=ax, label="Composite Score")
 
    plt.tight_layout()
    plt.savefig("../results/plots/plot2_scatter.png", dpi=150, bbox_inches="tight")
    print("Saved: ../results/plots/plot2_scatter.png")
    plt.show()
    plt.close()
 
 
# ── Plot 3: IC series + NAV curve for the top factor ─────────────────────────
 
def plot_top_factor_detail(results, factor_results, returns):
    top_expr  = results.iloc[0]["factor"]
    top_score = results.iloc[0]["score"]
    factor_df = factor_results[top_expr]
 
    ic     = compute_ic_series(factor_df, returns).dropna()
    ls_ret = compute_long_short_returns(factor_df, returns).dropna()
    nav    = (1 + ls_ret).cumprod()
 
    fig = plt.figure(figsize=(14, 5))
    gs  = gridspec.GridSpec(1, 2, figure=fig, wspace=0.3)
 
    # Left: IC time series
    ax1 = fig.add_subplot(gs[0, 0])
    ic.plot(ax=ax1, color="#90CAF9", alpha=0.4, linewidth=0.8, label="Daily IC")
    ic.rolling(20).mean().plot(ax=ax1, color="#1565C0", linewidth=2, label="20D Rolling Mean")
    ax1.axhline(0, color="black", linewidth=0.8, linestyle="--")
    ax1.set_title("IC Time Series — Top Factor", fontsize=10)
    ax1.set_ylabel("IC")
    ax1.legend(fontsize=8)
 
    # Right: NAV curve
    ax2 = fig.add_subplot(gs[0, 1])
    nav.plot(ax=ax2, color="#2E7D32", linewidth=2)
    ax2.fill_between(nav.index, 1, nav.values, alpha=0.1, color="#2E7D32")
    ax2.axhline(1, color="black", linewidth=0.8, linestyle="--")
    ax2.set_title("Long-Short Portfolio NAV", fontsize=10)
    ax2.set_ylabel("Net Asset Value")
 
    label = top_expr[:60] + ("..." if len(top_expr) > 60 else "")
    fig.suptitle(f"#{1}  {label}  (score={top_score})", fontsize=10, y=1.02)
 
    plt.tight_layout()
    plt.savefig("../results/plots/plot3_top_factor.png", dpi=150, bbox_inches="tight")
    print("Saved: ../results/plots/plot3_top_factor.png")
    plt.show()
    plt.close()

# %%
factor_results = compute_all_factors(factors, data)
results        = evaluate_all_factors(factor_results, returns)

plot_score_ranking(results)
plot_icir_vs_sharpe(results)
plot_top_factor_detail(results, factor_results, returns)
# Out:
# Computing factors:   0%|          | 0/216 [00:00<?, ?factor/s]
# Done: 216/216 factors computed successfully
# [1/216] Evaluating: rank(ts_mean(close, 5) - ts_mean(close, 20))
# [2/216] Evaluating: rank(ts_mean(returns, 20) / ts_std(returns, 20))
# [3/216] Evaluating: rank(close - ts_min(low, 20))
# [4/216] Evaluating: rank(ts_delta(vwap, 10) * (volume / adv20))
# [5/216] Evaluating: rank(ts_mean(close - open, 5))
# [6/216] Evaluating: rank((ts_mean(close, 20) - close) / ts_std(close, 20))
# [7/216] Evaluating: rank(open / close)
# [8/216] Evaluating: rank(ts_mean(returns, 20) - ts_mean(returns, 5))
# [9/216] Evaluating: rank((ts_max(high, 20) - close) / (ts_max(high, 20) - ts_min
# [10/216] Evaluating: rank(log(volume / adv20) * sign(ts_delta(close, 5)))
# /var/folders/g6/7_gx55l93snbqgq_jbkch3yw0000gn/T/ipykernel_60281/1207720711.py:23: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, _ = stats.spearmanr(f_row[valid], r_row[valid])
# [11/216] Evaluating: rank(ts_corr(returns, volume / adv20, 10))
# [12/216] Evaluating: rank((close - vwap) * (volume / adv20))
# [13/216] Evaluating: rank(ts_mean(volume, 5) / ts_std(close, 5))
# [14/216] Evaluating: rank(ts_corr(ts_delta(close, 1), ts_delta(volume, 1), 20))
# [15/216] Evaluating: rank(-ts_corr(ts_delta(close, 5), ts_mean(volume, 5) - volum
# [16/216] Evaluating: rank(ts_std(returns, 5) / ts_std(returns, 20))
# [17/216] Evaluating: rank(ts_std(close / ts_mean(close, 10), 20))
# [18/216] Evaluating: rank((high - low) / ts_mean(high - low, 20))
# [19/216] Evaluating: rank(ts_std(returns, 10) * (volume / adv20))
# [20/216] Evaluating: rank(ts_std(ts_std(returns, 5), 20))
# [21/216] Evaluating: ts_delta(close, 10) / ts_std(close, 10)
# [22/216] Evaluating: rank(ts_delta(close, 20) / close)
# [23/216] Evaluating: rank(close / ts_max(close, 60))
# [24/216] Evaluating: rank(close - ts_mean(close, 5)) - rank(close - ts_mean(close
# [25/216] Evaluating: ts_delta(close, 5) * rank(volume / adv20)
# [26/216] Evaluating: rank(ts_delta(close, 3) + ts_delta(close, 6) + ts_delta(clos
# [27/216] Evaluating: ts_delta(ts_delta(close, 5), 5)
# [28/216] Evaluating: rank(returns * volume)
# [29/216] Evaluating: rank(ts_mean(returns, 5)) - rank(ts_mean(returns, 20))
# [30/216] Evaluating: rank(close / ts_min(close, 20))
# [31/216] Evaluating: rank(vwap / ts_mean(vwap, 20))
# [32/216] Evaluating: ts_delta(close, 10) / (ts_max(close, 10) - ts_min(close, 10)
# [33/216] Evaluating: rank(ts_mean(returns, 3) / (ts_std(returns, 20) + 0.001))
# [34/216] Evaluating: rank(ts_delta(vwap, 10) / vwap)
# [35/216] Evaluating: sign(ts_delta(close, 5)) * rank(abs(ts_delta(close, 5)))
# [36/216] Evaluating: rank(close / ts_mean(close, 10)) * rank(close / ts_mean(clos
# [37/216] Evaluating: ts_mean(sign(returns), 10)
# [38/216] Evaluating: rank(ts_delta(high, 10))
# [39/216] Evaluating: rank((close - low) / (high - low + 0.001)) * rank(ts_delta(c
# [40/216] Evaluating: ts_delta(close, 20) / (ts_std(close, 60) + 0.001)
# [41/216] Evaluating: rank(ts_mean(close * volume, 5) / ts_mean(close * volume, 20
# [42/216] Evaluating: rank(ts_max(returns, 5))
# [43/216] Evaluating: ts_delta(rank(close), 10)
# [44/216] Evaluating: rank(ts_corr(rank(returns), rank(volume), 10))
# [45/216] Evaluating: rank(ts_delta(close, 5)) * sign(ts_delta(volume, 5))
# [46/216] Evaluating: zscore(ts_delta(close, 10)) + zscore(ts_delta(close, 20))
# [47/216] Evaluating: rank((close - ts_min(close, 20)) / (ts_max(close, 20) - ts_m
# [48/216] Evaluating: rank(ts_mean(returns * volume, 10) / (adv20 + 0.001))
# [49/216] Evaluating: ts_delta(ts_mean(close, 5), 5) / ts_std(close, 20)
# [50/216] Evaluating: rank(ts_delta(close, 40)) * rank(ts_delta(volume, 10))
# [51/216] Evaluating: rank(close / open) * rank(ts_delta(close, 10))
# [52/216] Evaluating: rank(ts_mean(high - low, 5) / ts_mean(high - low, 20))
# [53/216] Evaluating: ts_delta(close, 3) / (ts_max(high, 10) - ts_min(low, 10) + 0
# [54/216] Evaluating: rank(log(close) - log(ts_mean(close, 60)))
# [55/216] Evaluating: rank(ts_delta(close, 10)) - rank(ts_delta(close, 60))
# [56/216] Evaluating: zscore(ts_mean(returns, 5)) * zscore(ts_mean(volume, 5) / ad
# [57/216] Evaluating: rank(ts_mean(close / vwap, 10))
# [58/216] Evaluating: power(rank(ts_delta(close, 5)), 2) * sign(ts_delta(close, 5)
# [59/216] Evaluating: rank(ts_delta(close, 5) / close) - rank(ts_std(returns, 5))
# [60/216] Evaluating: rank(ts_delta(close, 10)) * rank(ts_mean(volume, 5) / ts_mea
# [61/216] Evaluating: ts_delta(rank(vwap), 5)
# [62/216] Evaluating: rank(ts_delta(high, 5) + ts_delta(low, 5))
# [63/216] Evaluating: rank(close - ts_mean(close, 10)) / (ts_std(close, 10) + 0.00
# [64/216] Evaluating: ts_mean(sign(returns) * rank(abs(returns)), 10)
# [65/216] Evaluating: rank(ts_delta(close, 5)) * rank(1 / (ts_std(returns, 10) + 0
# [66/216] Evaluating: rank(ts_mean(close, 5) / ts_mean(close, 20) - 1)
# [67/216] Evaluating: -1 * rank(ts_delta(close, 3) / close)
# [68/216] Evaluating: -1 * zscore(close / ts_mean(close, 10) - 1)
# [69/216] Evaluating: -1 * rank((close - ts_min(close, 20)) / (ts_max(close, 20) -
# [70/216] Evaluating: -1 * rank(close / vwap - 1)
# [71/216] Evaluating: rank(ts_mean(close, 60) / close - 1)
# [72/216] Evaluating: -1 * rank(ts_delta(close, 10) / ts_std(close, 20))
# [73/216] Evaluating: -1 * zscore(returns) * rank(volume / adv20)
# [74/216] Evaluating: rank(ts_mean(vwap, 20) / vwap - 1)
# [75/216] Evaluating: -1 * rank(ts_delta(close, 5)) * rank(ts_std(returns, 5))
# [76/216] Evaluating: -1 * rank((close - ts_mean(close, 20)) / ts_std(close, 20))
# [77/216] Evaluating: -1 * rank((close - ts_mean(close, 5)) / ts_std(close, 5))
# [78/216] Evaluating: -1 * sign(close - ts_mean(close, 10)) * rank(abs(close - ts_
# [79/216] Evaluating: rank(ts_mean(returns, 20)) * -1
# [80/216] Evaluating: -1 * rank(ts_mean(returns, 3))
# [81/216] Evaluating: rank(log(ts_mean(volume, 5)) - log(volume))
# [82/216] Evaluating: -1 * rank(close - open) * rank(abs(returns))
# [83/216] Evaluating: -1 * rank(ts_delta(vwap, 5) / ts_std(vwap, 20))
# [84/216] Evaluating: rank(ts_mean(close, 40) - close) / rank(ts_std(close, 40))
# [85/216] Evaluating: -1 * rank((high - low) / close) * sign(returns)
# [86/216] Evaluating: -1 * rank(ts_max(close, 10) / close - 1) * sign(ts_delta(clo
# [87/216] Evaluating: -1 * zscore(close / ts_mean(close, 20) - 1) * zscore(volume
# [88/216] Evaluating: rank(1 - close / ts_max(close, 60))
# [89/216] Evaluating: -1 * rank(ts_delta(close, 1) / ts_std(close, 10))
# [90/216] Evaluating: -1 * rank(power(returns, 3))
# [91/216] Evaluating: rank(ts_min(close, 10) / close - 1) * -1
# [92/216] Evaluating: -1 * rank(ts_corr(close, volume, 5)) * rank(abs(ts_delta(clo
# [93/216] Evaluating: rank(ts_mean(low, 10) / close - 1)
# [94/216] Evaluating: -1 * rank(ts_delta(close, 5) + ts_delta(close, 10))
# [95/216] Evaluating: -1 * zscore((high + low + close) / 3 / ts_mean((high + low +
# [96/216] Evaluating: rank(adv20 / volume) * sign(ts_mean(close, 10) - close)
# [97/216] Evaluating: -1 * rank(ts_delta(high, 5) / ts_std(high, 20))
# [98/216] Evaluating: -1 * rank((close - open) / (high - low + 0.0001))
# [99/216] Evaluating: -1 * rank(ts_mean(returns, 5)) * rank(ts_std(returns, 5))
# [100/216] Evaluating: rank(vwap / close - 1) * rank(volume / adv20)
# [101/216] Evaluating: -1 * rank(ts_delta(close / vwap, 5))
# [102/216] Evaluating: rank(ts_mean(open, 10) / open - 1)
# [103/216] Evaluating: -1 * rank(ts_delta(close, 20) / close) * rank(1 / ts_std(ret
# [104/216] Evaluating: rank(ts_corr(returns, volume, 10)) * -1
# [105/216] Evaluating: -1 * rank(ts_delta(ts_mean(close, 5), 5))
# [106/216] Evaluating: rank(ts_min(low, 20) / close - 1) * -1 + rank(1 - close / ts
# [107/216] Evaluating: -1 * zscore(ts_delta(close, 2)) * zscore(ts_delta(close, 2)
# [108/216] Evaluating: rank(ts_mean(volume, 20) / ts_mean(volume, 5) - 1) * sign(ts
# [109/216] Evaluating: -1 * rank(ts_mean(high / close - 1, 10))
# [110/216] Evaluating: -1 * rank(ts_delta(close, 5)) * rank(ts_delta(volume, 5) / a
# [111/216] Evaluating: rank(ts_corr(close, volume, 5))
# [112/216] Evaluating: rank(ts_corr(close, volume, 20)) - rank(ts_corr(close, volum
# [113/216] Evaluating: rank(ts_corr(abs(returns), volume, 10))
# [114/216] Evaluating: rank(ts_corr(vwap - close, volume, 10))
# [115/216] Evaluating: zscore(ts_mean(returns * volume, 10) / ts_mean(volume, 10))
# [116/216] Evaluating: rank(ts_mean(returns * (volume / adv20), 5))
# [117/216] Evaluating: rank(ts_delta(volume, 5) * ts_delta(close, 5))
# [118/216] Evaluating: -1 * rank(ts_delta(volume, 5) * ts_delta(close, 5)) * sign(t
# [119/216] Evaluating: rank(close / vwap)
# [120/216] Evaluating: rank(ts_mean(close / vwap, 5))
# [121/216] Evaluating: rank(ts_mean((close - vwap) * volume, 10))
# [122/216] Evaluating: rank(ts_mean((close - vwap) / vwap, 10)) * rank(volume / adv
# [123/216] Evaluating: zscore((close - vwap) / (high - low + 0.0001))
# [124/216] Evaluating: rank(ts_corr(vwap, volume, 15))
# [125/216] Evaluating: -1 * rank(ts_corr(rank(close), rank(volume), 10))
# [126/216] Evaluating: rank(ts_mean(volume * sign(returns), 20) / ts_mean(volume, 2
# [127/216] Evaluating: rank(ts_mean(volume * sign(returns), 10) / adv20)
# [128/216] Evaluating: rank(ts_mean(volume * returns, 10) / ts_std(volume * returns
# [129/216] Evaluating: rank(log(volume / adv20) * returns)
# [130/216] Evaluating: rank(ts_delta(close, 10)) * rank(ts_delta(volume, 10))
# [131/216] Evaluating: -1 * rank(ts_delta(close, 10)) * (1 - rank(ts_delta(volume,
# [132/216] Evaluating: rank(ts_std(volume, 10) / ts_mean(volume, 10)) * sign(ts_del
# [133/216] Evaluating: rank(ts_min(volume, 10) / ts_max(volume, 10)) * rank(returns
# [134/216] Evaluating: rank((close - ts_min(close, 20)) / (ts_max(close, 20) - ts_m
# [135/216] Evaluating: rank(ts_corr((high - low) / close, volume / adv20, 10))
# [136/216] Evaluating: -1 * rank(ts_corr(ts_mean(close, 5), ts_mean(volume, 5), 20)
# [137/216] Evaluating: rank(ts_mean((high - close) / (high - low + 0.0001) * volume
# [138/216] Evaluating: -1 * rank(ts_mean((close - low) / (high - low + 0.0001) * vo
# [139/216] Evaluating: zscore(ts_delta(volume / adv20, 5)) * sign(ts_delta(close, 5
# [140/216] Evaluating: rank(ts_corr(close, log(volume), 10)) - rank(ts_corr(close,
# [141/216] Evaluating: rank(ts_mean(abs(returns) / (volume / adv20 + 0.0001), 10))
# [142/216] Evaluating: -1 * rank(ts_mean(abs(returns) / (volume / adv20 + 0.0001),
# [143/216] Evaluating: rank(ts_corr(power(returns, 2), volume, 15))
# [144/216] Evaluating: rank(ts_mean(sign(returns) * log(volume / adv20 + 1), 20))
# [145/216] Evaluating: rank(ts_max(volume, 20) / adv20) * rank(ts_delta(close, 20))
# [146/216] Evaluating: -1 * rank(ts_max(volume, 10) / adv20) * rank(close / ts_max(
# [147/216] Evaluating: rank(ts_corr(low, volume, 10)) - rank(ts_corr(high, volume,
# [148/216] Evaluating: rank(ts_mean((vwap - open) / (open + 0.0001) * volume, 10))
# [149/216] Evaluating: zscore(ts_mean(returns * power(volume / adv20, 2), 10))
# [150/216] Evaluating: rank(ts_delta(ts_corr(close, volume, 10), 5))
# [151/216] Evaluating: rank(ts_std(returns * volume, 10) / (ts_std(returns, 10) * t
# [152/216] Evaluating: rank((close - vwap) / (ts_std(close, 20) + 0.0001)) * rank(v
# [153/216] Evaluating: -1 * rank(ts_mean(ts_delta(volume, 1) * ts_delta(close, 1),
# [154/216] Evaluating: rank(ts_std(returns, 5) / ts_std(returns, 60))
# [155/216] Evaluating: rank(-ts_std(returns, 20))
# [156/216] Evaluating: zscore(ts_mean(high - low, 5) / ts_mean(high - low, 60))
# [157/216] Evaluating: rank(ts_std(returns, 5)) * sign(ts_delta(close, 5))
# [158/216] Evaluating: rank(ts_delta(ts_std(returns, 20), 10))
# [159/216] Evaluating: rank(log(high / low))
# [160/216] Evaluating: rank(ts_mean(log(high / low), 10))
# [161/216] Evaluating: zscore(ts_std(volume, 10) / ts_mean(volume, 10))
# [162/216] Evaluating: rank(ts_std(returns, 10) - ts_std(returns, 60))
# [163/216] Evaluating: rank(ts_max(high, 20) - ts_min(low, 20)) / ts_mean(close, 20
# [164/216] Evaluating: -rank(ts_std(ts_std(returns, 10), 20))
# [165/216] Evaluating: rank(ts_corr(ts_std(returns, 5), volume, 20))
# [166/216] Evaluating: zscore(ts_mean(abs(returns), 10))
# [167/216] Evaluating: rank(ts_mean(abs(close - vwap), 10) / ts_mean(close, 10))
# [168/216] Evaluating: -rank(ts_std(returns, 5) / ts_mean(abs(returns), 5))
# [169/216] Evaluating: rank(ts_min(ts_std(returns, 10), 20))
# [170/216] Evaluating: zscore(ts_std(returns, 20)) * zscore(-ts_delta(close, 20) /
# [171/216] Evaluating: rank((high - low) / (ts_max(high, 10) - ts_min(low, 10) + 0.
# [172/216] Evaluating: rank(ts_corr(abs(returns), volume / adv20, 20))
# [173/216] Evaluating: zscore(ts_delta(ts_mean(high - low, 5), 5))
# [174/216] Evaluating: rank(ts_std(close / vwap, 20))
# [175/216] Evaluating: -rank(power(ts_std(returns, 20), 2))
# [176/216] Evaluating: rank(ts_mean(abs(returns), 5) / ts_mean(abs(returns), 60))
# [177/216] Evaluating: rank(ts_std(high - low, 10) / ts_mean(high - low, 10))
# [178/216] Evaluating: zscore(ts_max(returns, 20) - ts_min(returns, 20))
# [179/216] Evaluating: rank(ts_corr(ts_std(returns, 5), ts_delta(close, 5), 20))
# [180/216] Evaluating: -rank(ts_mean(power(returns, 2), 20))
# [181/216] Evaluating: rank((ts_max(high, 10) - close) / (ts_max(high, 10) - ts_min
# [182/216] Evaluating: zscore(ts_std(open - close, 10) / ts_mean(close, 10))
# [183/216] Evaluating: rank(ts_delta(log(high / low), 5))
# [184/216] Evaluating: rank(ts_std(returns, 10)) - rank(ts_std(returns, 60))
# [185/216] Evaluating: rank(ts_corr(high - low, volume, 20))
# [186/216] Evaluating: zscore(ts_mean(high - close, 10) / ts_mean(close - low, 10))
# [187/216] Evaluating: -rank(ts_max(abs(returns), 20))
# [188/216] Evaluating: rank(ts_std(returns, 10) * ts_mean(volume, 10) / adv20)
# [189/216] Evaluating: zscore(ts_min(low, 10) / ts_max(high, 10))
# [190/216] Evaluating: rank(ts_delta(ts_mean(abs(close - open), 5), 5))
# [191/216] Evaluating: rank(ts_corr(returns, ts_std(returns, 5), 20))
# [192/216] Evaluating: -zscore(ts_mean(high - low, 5) / close)
# [193/216] Evaluating: rank(ts_std(close - ts_mean(close, 5), 20))
# [194/216] Evaluating: rank(ts_std(volume, 20) / adv20) * sign(-ts_delta(ts_std(ret
# [195/216] Evaluating: zscore(ts_mean(high / low, 20)) * rank(-ts_std(returns, 20))
# [196/216] Evaluating: rank(ts_corr(ts_std(returns, 10), adv20, 20))
# [197/216] Evaluating: rank(ts_std(vwap / close, 20))
# [198/216] Evaluating: -rank(ts_mean(power(returns - ts_mean(returns, 20), 2), 20))
# [199/216] Evaluating: rank(ts_delta(vwap, 10) / ts_std(close, 20))
# [200/216] Evaluating: rank(ts_delta(ts_delta(close, 5), 5) / close)
# [201/216] Evaluating: rank((close - ts_min(close, 20)) / (ts_max(close, 20) - ts_m
# [202/216] Evaluating: rank(ts_mean(returns, 5)) - rank(ts_mean(returns, 60))
# [203/216] Evaluating: zscore(ts_mean(returns, 10)) * rank(ts_corr(close, volume, 1
# [204/216] Evaluating: -rank((close - ts_min(close, 10)) / (ts_max(close, 10) - ts_
# [205/216] Evaluating: rank((ts_mean(vwap, 10) - close) / close)
# [206/216] Evaluating: -rank(ts_delta(close, 3) / ts_std(close, 20)) * rank(volume
# [207/216] Evaluating: rank(ts_mean(close, 50) / close - 1) * rank(ts_std(returns,
# [208/216] Evaluating: rank(ts_mean(returns * (volume / adv20), 10))
# [209/216] Evaluating: rank(ts_delta(volume, 5) / adv20) * sign(-ts_delta(close, 5)
# [210/216] Evaluating: zscore((close - vwap) / close * log(volume / adv20 + 1))
# [211/216] Evaluating: rank(ts_mean((high - low) / vwap, 5) / ts_mean(volume / adv2
# [212/216] Evaluating: rank(-1 * ts_std(returns, 20))
# [213/216] Evaluating: zscore(ts_std(returns, 5) / ts_std(returns, 60))
# [214/216] Evaluating: rank(-1 * ts_mean((high - low) / close, 10))
# [215/216] Evaluating: rank(close / (ts_max(high, 20) - ts_min(low, 20)))
# [216/216] Evaluating: rank(ts_corr(abs(returns), volume / adv20, 15))
# Saved: ../results/plots/plot1_ranking.png
# Saved: ../results/plots/plot2_scatter.png
# /var/folders/g6/7_gx55l93snbqgq_jbkch3yw0000gn/T/ipykernel_60281/1272580343.py:95: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Saved: ../results/plots/plot3_top_factor.png

# %%
top20 = (
    results.sort_values("score", ascending=False)
           .loc[:, ["factor", "score", "IC_mean", "ICIR", "Sharpe", "MDD", "Turnover"]]
           .reset_index(drop=True)
           .head(20)
)

top20.index = top20.index + 1
print(top20)
# Out:
#                                                factor   score  IC_mean  \
# 1       rank(vwap / close - 1) * rank(volume / adv20)  0.7556   0.0169
# 2         -1 * zscore(returns) * rank(volume / adv20)  0.7338   0.0180
# 3   -rank((close - ts_min(close, 10)) / (ts_max(cl...  0.7303   0.0145
# 4                        -1 * rank(power(returns, 3))  0.7250   0.0179
# 5                                  rank(open / close)  0.7194   0.0154
# 6   -1 * rank(ts_delta(close, 1) / ts_std(close, 10))  0.7092   0.0168
# 7   -1 * rank((close - open) / (high - low + 0.0001))  0.6923   0.0148
# 8     -1 * rank((high - low) / close) * sign(returns)  0.6910   0.0148
# 9   -1 * rank(ts_delta(close, 10) / ts_std(close, ...  0.6819   0.0145
# 10       rank(ts_std(returns, 10) * (volume / adv20))  0.6756   0.0133
# 11  -1 * rank((close - ts_mean(close, 5)) / ts_std...  0.6701   0.0159
# 12    rank(ts_corr(abs(returns), volume / adv20, 15))  0.6696   0.0083
# 13  -1 * sign(close - ts_mean(close, 10)) * rank(a...  0.6687   0.0156
# 14        -1 * zscore(close / ts_mean(close, 10) - 1)  0.6687   0.0156
# 15          rank((ts_mean(vwap, 10) - close) / close)  0.6621   0.0153
# 16  rank(ts_mean((high - close) / (high - low + 0....  0.6580   0.0054
# 17            rank(ts_corr(abs(returns), volume, 10))  0.6570   0.0083
# 18  -1 * rank((close - ts_mean(close, 20)) / ts_st...  0.6547   0.0139
# 19  rank((ts_mean(close, 20) - close) / ts_std(clo...  0.6547   0.0139
# 20       rank(ts_corr(power(returns, 2), volume, 15))  0.6487   0.0080
#
#       ICIR  Sharpe     MDD  Turnover
# 1   0.1420  1.0861 -0.1830    0.7077
# 2   0.1111  1.3615 -0.1408    0.6850
# 3   0.0881  1.9927 -0.0730    0.5955
# 4   0.1031  1.3031 -0.1682    0.7146
# 5   0.0962  1.4001 -0.1833    0.7119
# 6   0.1052  1.0751 -0.1915    0.7295
# 7   0.1006  1.2029 -0.1607    0.7889
# 8   0.0898  1.1474 -0.1745    0.5982
# 9   0.0871  1.1678 -0.1200    0.4292
# 10  0.0824  1.1734 -0.1343    0.4346
# 11  0.0973  0.9577 -0.1495    0.7481
# 12  0.0946  1.2013 -0.0822    0.2197
# 13  0.0860  0.8605 -0.1354    0.3406
# 14  0.0860  0.8605 -0.1354    0.3406
# 15  0.0848  0.8144 -0.1349    0.3345
# 16  0.0489  1.5503 -0.1320    0.0564
# 17  0.0958  1.1233 -0.0757    0.2953
# 18  0.0816  0.8370 -0.1475    0.3860
# 19  0.0816  0.8370 -0.1475    0.3860
# 20  0.0928  0.8617 -0.1202    0.2101

# %%
print(type(results))
print(results.columns)
print(results.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['IC_mean', 'ICIR', 'Sharpe', 'MDD', 'Turnover', 'factor', 'score'], dtype='object')
#       IC_mean    ICIR  Sharpe     MDD  Turnover  \
# rank
# 1      0.0169  0.1420  1.0861 -0.1830    0.7077
# 2      0.0180  0.1111  1.3615 -0.1408    0.6850
# 3      0.0145  0.0881  1.9927 -0.0730    0.5955
# 4      0.0179  0.1031  1.3031 -0.1682    0.7146
# 5      0.0154  0.0962  1.4001 -0.1833    0.7119
#
#                                                  factor   score
# rank
# 1         rank(vwap / close - 1) * rank(volume / adv20)  0.7556
# 2           -1 * zscore(returns) * rank(volume / adv20)  0.7338
# 3     -rank((close - ts_min(close, 10)) / (ts_max(cl...  0.7303
# 4                          -1 * rank(power(returns, 3))  0.7250
# 5                                    rank(open / close)  0.7194

# %% [markdown]
# ## Timing Infrastructure

# %%
# Save timing data to CSV
timing_df = pd.DataFrame(list(timing.items()), columns=['function', 'time'])
timing_df.to_csv("../results/timing/opt3_timing.csv", index=False)
print("Timing data saved to ../results/timing/opt3_timing.csv")
print(timing_df)
# Out:
# Timing data saved to ../results/timing/opt3_timing.csv
#                function        time
# 0   compute_all_factors    3.657208
# 1  evaluate_all_factors  190.799987

# %% [markdown]
# ## Part X: line_profiler Performance Analysis (Opt3)
#
# Make sure it is installed first: `pip install line_profiler`
#
# Recommended to run in Jupyter first:
#
# - `%load_ext line_profiler`
# - Then run the two `%lprun` cells below
#
# **Note**: `line_profiler` adds 3–10× overhead. Trust wall-clock numbers from
# the `timing` dict for cross-variant comparison; use `%lprun` only to diagnose
# *where* time is spent within a single variant. By Opt3, `ts_corr` and `rank`
# will be the largest remaining hotspots — Numba-JITing them is the natural
# next step.

# %%
# If this is your first use, install in terminal first:
# pip install line_profiler

# %load_ext line_profiler

# %%
# 1) Check overall bottleneck: compute_all_factors
# %lprun -f compute_all_factors compute_all_factors(factors, data)

# %%
# 2) Check key operators in class internals (rolling corr and rank are the
# remaining hotspots in Opt3)
bt_profile = Opt3Backtester(data)
# %lprun -f bt_profile.ts_corr -f bt_profile.rank -f bt_profile.compute_factor bt_profile.compute_factor(factors[0]['factor'])
